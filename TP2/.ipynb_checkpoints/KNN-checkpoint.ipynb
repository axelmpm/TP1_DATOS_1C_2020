# %% [markdown]
# # PLOT: Top usuarios mas mencionados en tweets

# %%
#IMPORTS
# %run Functions.ipynb
import pandas as pd
import numpy as np
import random
import seaborn as sns
import matplotlib
import matplotlib.pyplot as plt
import warnings
import time
import category_encoders as ce

from sklearn.metrics import f1_score
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import OneHotEncoder 
from sklearn.preprocessing import Imputer

# %%
# Predictions de juguete
n =3263
predictions = np.arange(n)
for i in range(len(predictions)):
    predictions[i]=random.choice([0,1])

# %%
#CARGA DATA
train = pd.read_csv("Data/train.csv")
to_predict = pd.read_csv("Data/test.csv")

# %% [markdown]
# ### Completo cosas

# %%
train.drop(columns=["id"])
train.fillna("Nothing", inplace= True)

len_(train)
train['keyword'] = train['keyword'].str.replace('%',' ')
train['keyword'] = train['keyword'].str.replace('2','')
train['keyword'] = train['keyword'].str.replace('0','')

# %% [markdown]
# ### Pongo algun Feature

# %%
train["Tiene_key_impor"] = (train["keyword"] == "wreckage") | (train["keyword"] == "debris")\
| (train["keyword"] == "derailment") | (train["keyword"] == "outbreak") | (train["keyword"] == "oil split")\
| (train["keyword"] == "typhoon") | (train["keyword"] == "suicide bombing") | (train["keyword"] == "suicide bomber")

train["Tiene_key_no_impor"] = (train["keyword"] == "aftershock")

from sklearn.preprocessing import LabelEncoder

# Categorical boolean mask
categorical_feature_mask = train.dtypes==object
# filter categorical columns using mask and turn it into a list
categorical_cols = train.columns[categorical_feature_mask].tolist()

le = LabelEncoder()

# apply le on categorical feature columns
train[categorical_cols] = train[categorical_cols].apply(lambda col: le.fit_transform(col))

# %%
x = train[train.columns.drop("target")]
y = train['target']

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.20)

print(f"Original shapes: X={x.shape} y={y.shape}")
print(f"Train shapes: X={x_train.shape} y={y_train.shape}")
print(f"Test  shapes: X={x_test.shape}  y={y_test.shape}")
# Out:
# Original shapes: X=(7613, 7) y=(7613,)
# Train shapes: X=(6090, 7) y=(6090,)
# Test  shapes: X=(1523, 7)  y=(1523,)

# %%
train.head(50)
# Out:
#     id  keyword  location  text  target  len  Tiene_key_impor  \
# 0    1        0      1906  5102       1   69            False
# 1    4        0      1906  3391       1   38            False
# 2    5        0      1906  2322       1  133            False
# 3    6        0      1906   658       1   65            False
# 4    7        0      1906  4373       1   88            False
# 5    8        0      1906   195       1  110            False
# 6   10        0      1906   282       1   95            False
# 7   13        0      1906  4055       1   59            False
# 8   14        0      1906  6255       1   79            False
# 9   15        0      1906  4025       1   52            False
# 10  16        0      1906  6330       1   43            False
# 11  17        0      1906  3559       1  129            False
# 12  18        0      1906   352       1   76            False
# 13  19        0      1906    83       1   39            False
# 14  20        0      1906  2939       1   56            False
# 15  23        0      1906  6776       0   14            False
# 16  24        0      1906  3925       0   13            False
# 17  25        0      1906  5923       0   16            False
# 18  26        0      1906  4773       0   17            False
# 19  28        0      1906  6751       0   28            False
# 20  31        0      1906  7402       0   22            False
# 21  32        0      1906  4522       0   17            False
# 22  33        0      1906  4554       0   11            False
# 23  34        0      1906  6753       0   21            False
# 24  36        0      1906  4427       0    8            False
# 25  37        0      1906  4949       0   30            False
# 26  38        0      1906  6652       0   21            False
# 27  39        0      1906  4553       0   18            False
# 28  40        0      1906  2840       0    9            False
# 29  41        0      1906  3033       0   18            False
# 30  44        0      1906  6172       0    8            False
# 31  48        1       453  1689       1   55            False
# 32  49        1       922  6695       0   67            False
# 33  50        1       209    20       1   82            False
# 34  52        1      2055  2890       0   34            False
# 35  53        1      1516  5059       0   76            False
# 36  54        1      2115  1372       0  122            False
# 37  55        1      2865  4092       1   55            False
# 38  56        1      1906  2510       1  140            False
# 39  57        1      2021  2264       0   22            False
# 40  59        1      1493  2765       0  114            False
# 41  61        1      1906  7321       0   62            False
# 42  62        1      3118  3556       0  120            False
# 43  63        1      1906  5599       0   44            False
# 44  64        1      1906  3992       0   92            False
# 45  65        1      1906  3828       0   96            False
# 46  66        1      1012  3717       1   97            False
# 47  67        1      1906  2631       0   63            False
# 48  68        1      1493  2765       0  114            False
# 49  71        1       905  3354       0  138            False
#
#     Tiene_key_no_impor
# 0                False
# 1                False
# 2                False
# 3                False
# 4                False
# 5                False
# 6                False
# 7                False
# 8                False
# 9                False
# 10               False
# 11               False
# 12               False
# 13               False
# 14               False
# 15               False
# 16               False
# 17               False
# 18               False
# 19               False
# 20               False
# 21               False
# 22               False
# 23               False
# 24               False
# 25               False
# 26               False
# 27               False
# 28               False
# 29               False
# 30               False
# 31               False
# 32               False
# 33               False
# 34               False
# 35               False
# 36               False
# 37               False
# 38               False
# 39               False
# 40               False
# 41               False
# 42               False
# 43               False
# 44               False
# 45               False
# 46               False
# 47               False
# 48               False
# 49               False

# %% [markdown]
# ### Fit

# %%
k = list(range(2,40))
prueba = pd.DataFrame(k,index=k,columns=["Kactual"])

# %%
dists = [
"euclidean",
"manhattan",
"chebyshev"]


knn_best_distance(prueba,dists,x_train,y_train,x_test,y_test)
# Out:
# euclidean --------------------------
# con k:  2
# Entrenamiento: 80.1642%
# Testeo: 62.1142%.
# F1 score: 0.4236.
#
# con k:  3
# Entrenamiento: 80.0985%
# Testeo: 60.0788%.
# F1 score: 0.5190.
#
# con k:  4
# Entrenamiento: 74.6470%
# Testeo: 61.5233%.
# F1 score: 0.4355.
#
# con k:  5
# Entrenamiento: 74.6470%
# Testeo: 60.2758%.
# F1 score: 0.5021.
#
# con k:  6
# Entrenamiento: 71.4286%
# Testeo: 61.3263%.
# F1 score: 0.4490.
#
# con k:  7
# Entrenamiento: 71.3793%
# Testeo: 60.0131%.
# F1 score: 0.5101.
#
# con k:  8
# Entrenamiento: 70.0821%
# Testeo: 60.0131%.
# F1 score: 0.4397.
#
# con k:  9
# Entrenamiento: 69.3760%
# Testeo: 59.2252%.
# F1 score: 0.4947.
#
# con k:  10
# Entrenamiento: 68.6535%
# Testeo: 60.3414%.
# F1 score: 0.4428.
#
# con k:  11
# Entrenamiento: 68.7521%
# Testeo: 59.5535%.
# F1 score: 0.4858.
#
# con k:  12
# Entrenamiento: 67.9639%
# Testeo: 60.6697%.
# F1 score: 0.4500.
#
# con k:  13
# Entrenamiento: 67.9475%
# Testeo: 60.2101%.
# F1 score: 0.4899.
#
# con k:  14
# Entrenamiento: 66.9622%
# Testeo: 60.2101%.
# F1 score: 0.4358.
#
# con k:  15
# Entrenamiento: 67.1757%
# Testeo: 60.6697%.
# F1 score: 0.4971.
#
# con k:  16
# Entrenamiento: 66.2890%
# Testeo: 60.6697%.
# F1 score: 0.4438.
#
# con k:  17
# Entrenamiento: 66.2397%
# Testeo: 59.8818%.
# F1 score: 0.4844.
#
# con k:  18
# Entrenamiento: 65.7635%
# Testeo: 60.0788%.
# F1 score: 0.4318.
#
# con k:  19
# Entrenamiento: 65.7307%
# Testeo: 60.5384%.
# F1 score: 0.4832.
#
# con k:  20
# Entrenamiento: 65.4844%
# Testeo: 60.3414%.
# F1 score: 0.4334.
#
# con k:  21
# Entrenamiento: 65.6814%
# Testeo: 60.0131%.
# F1 score: 0.4718.
#
# con k:  22
# Entrenamiento: 65.2217%
# Testeo: 61.0637%.
# F1 score: 0.4400.
#
# con k:  23
# Entrenamiento: 65.2381%
# Testeo: 60.2101%.
# F1 score: 0.4675.
#
# con k:  24
# Entrenamiento: 65.0739%
# Testeo: 60.8667%.
# F1 score: 0.4409.
#
# con k:  25
# Entrenamiento: 65.1067%
# Testeo: 60.5384%.
# F1 score: 0.4677.
#
# con k:  26
# Entrenamiento: 64.8768%
# Testeo: 61.2607%.
# F1 score: 0.4402.
#
# con k:  27
# Entrenamiento: 64.9754%
# Testeo: 61.1293%.
# F1 score: 0.4705.
#
# con k:  28
# Entrenamiento: 64.5977%
# Testeo: 60.8011%.
# F1 score: 0.4341.
#
# con k:  29
# Entrenamiento: 64.6634%
# Testeo: 61.1950%.
# F1 score: 0.4709.
#
# con k:  30
# Entrenamiento: 64.6305%
# Testeo: 60.9324%.
# F1 score: 0.4371.
#
# con k:  31
# Entrenamiento: 64.4171%
# Testeo: 60.4071%.
# F1 score: 0.4592.
#
# con k:  32
# Entrenamiento: 64.3186%
# Testeo: 60.3414%.
# F1 score: 0.4269.
#
# con k:  33
# Entrenamiento: 64.3514%
# Testeo: 59.7505%.
# F1 score: 0.4452.
#
# con k:  34
# Entrenamiento: 64.1379%
# Testeo: 60.0788%.
# F1 score: 0.4198.
#
# con k:  35
# Entrenamiento: 64.2036%
# Testeo: 59.8162%.
# F1 score: 0.4365.
#
# con k:  36
# Entrenamiento: 63.9573%
# Testeo: 59.6848%.
# F1 score: 0.4085.
#
# con k:  37
# Entrenamiento: 63.9573%
# Testeo: 60.0788%.
# F1 score: 0.4391.
#
# con k:  38
# Entrenamiento: 64.0887%
# Testeo: 60.2758%.
# F1 score: 0.4166.
#
# con k:  39
# Entrenamiento: 63.6617%
# Testeo: 60.3414%.
# F1 score: 0.4355.
#
# manhattan --------------------------
# con k:  2
# Entrenamiento: 80.8867%
# Testeo: 63.5588%.
# F1 score: 0.4489.
#
# con k:  3
# Entrenamiento: 80.7882%
# Testeo: 61.6546%.
# F1 score: 0.5387.
#
# con k:  4
# Entrenamiento: 75.4187%
# Testeo: 62.7708%.
# F1 score: 0.4666.
#
# con k:  5
# Entrenamiento: 75.6158%
# Testeo: 60.4728%.
# F1 score: 0.5137.
#
# con k:  6
# Entrenamiento: 72.9392%
# Testeo: 61.9829%.
# F1 score: 0.4654.
#
# con k:  7
# Entrenamiento: 72.3645%
# Testeo: 61.8516%.
# F1 score: 0.5303.
#
# con k:  8
# Entrenamiento: 70.9195%
# Testeo: 62.7708%.
# F1 score: 0.4765.
#
# con k:  9
# Entrenamiento: 71.2479%
# Testeo: 62.0486%.
# F1 score: 0.5270.
#
# con k:  10
# Entrenamiento: 70.1314%
# Testeo: 63.2305%.
# F1 score: 0.4937.
#
# con k:  11
# Entrenamiento: 70.1149%
# Testeo: 62.4425%.
# F1 score: 0.5265.
#
# con k:  12
# Entrenamiento: 69.5402%
# Testeo: 62.7708%.
# F1 score: 0.4850.
#
# con k:  13
# Entrenamiento: 69.3760%
# Testeo: 62.0486%.
# F1 score: 0.5262.
#
# con k:  14
# Entrenamiento: 68.7521%
# Testeo: 63.0991%.
# F1 score: 0.4937.
#
# con k:  15
# Entrenamiento: 68.3087%
# Testeo: 62.8365%.
# F1 score: 0.5268.
#
# con k:  16
# Entrenamiento: 68.1117%
# Testeo: 63.0991%.
# F1 score: 0.4863.
#
# con k:  17
# Entrenamiento: 67.7668%
# Testeo: 61.9829%.
# F1 score: 0.5039.
#
# con k:  18
# Entrenamiento: 67.2742%
# Testeo: 63.1648%.
# F1 score: 0.4829.
#
# con k:  19
# Entrenamiento: 67.3727%
# Testeo: 62.8365%.
# F1 score: 0.5195.
#
# con k:  20
# Entrenamiento: 66.9951%
# Testeo: 62.1799%.
# F1 score: 0.4686.
#
# con k:  21
# Entrenamiento: 67.2085%
# Testeo: 62.0486%.
# F1 score: 0.5034.
#
# con k:  22
# Entrenamiento: 66.7159%
# Testeo: 62.2456%.
# F1 score: 0.4641.
#
# con k:  23
# Entrenamiento: 66.8144%
# Testeo: 61.3920%.
# F1 score: 0.4913.
#
# con k:  24
# Entrenamiento: 66.5517%
# Testeo: 62.1799%.
# F1 score: 0.4696.
#
# con k:  25
# Entrenamiento: 66.6667%
# Testeo: 61.9173%.
# F1 score: 0.4948.
#
# con k:  26
# Entrenamiento: 66.2069%
# Testeo: 62.0486%.
# F1 score: 0.4648.
#
# con k:  27
# Entrenamiento: 66.4204%
# Testeo: 61.2607%.
# F1 score: 0.4825.
#
# con k:  28
# Entrenamiento: 66.0263%
# Testeo: 61.3920%.
# F1 score: 0.4525.
#
# con k:  29
# Entrenamiento: 66.2233%
# Testeo: 61.0637%.
# F1 score: 0.4701.
#
# con k:  30
# Entrenamiento: 65.6814%
# Testeo: 60.6697%.
# F1 score: 0.4386.
#
# con k:  31
# Entrenamiento: 65.9442%
# Testeo: 61.1950%.
# F1 score: 0.4690.
#
# con k:  32
# Entrenamiento: 65.8621%
# Testeo: 61.1950%.
# F1 score: 0.4398.
#
# con k:  33
# Entrenamiento: 65.7964%
# Testeo: 60.7354%.
# F1 score: 0.4574.
#
# con k:  34
# Entrenamiento: 65.4844%
# Testeo: 61.1950%.
# F1 score: 0.4387.
#
# con k:  35
# Entrenamiento: 65.5172%
# Testeo: 61.1293%.
# F1 score: 0.4628.
#
# con k:  36
# Entrenamiento: 65.0411%
# Testeo: 60.9980%.
# F1 score: 0.4354.
#
# con k:  37
# Entrenamiento: 65.1560%
# Testeo: 60.2758%.
# F1 score: 0.4465.
#
# con k:  38
# Entrenamiento: 64.5649%
# Testeo: 60.4728%.
# F1 score: 0.4223.
#
# con k:  39
# Entrenamiento: 64.9754%
# Testeo: 60.8011%.
# F1 score: 0.4488.
#
# chebyshev --------------------------
# con k:  2
# Entrenamiento: 79.4910%
# Testeo: 60.7354%.
# F1 score: 0.4103.
#
# con k:  3
# Entrenamiento: 79.6059%
# Testeo: 59.4879%.
# F1 score: 0.5176.
#
# con k:  4
# Entrenamiento: 73.7603%
# Testeo: 60.3414%.
# F1 score: 0.4237.
#
# con k:  5
# Entrenamiento: 73.4811%
# Testeo: 59.4222%.
# F1 score: 0.4951.
#
# con k:  6
# Entrenamiento: 70.5419%
# Testeo: 60.2101%.
# F1 score: 0.4336.
#
# con k:  7
# Entrenamiento: 70.4433%
# Testeo: 58.5686%.
# F1 score: 0.4832.
#
# con k:  8
# Entrenamiento: 69.4910%
# Testeo: 59.7505%.
# F1 score: 0.4381.
#
# con k:  9
# Entrenamiento: 68.7849%
# Testeo: 57.9777%.
# F1 score: 0.4771.
#
# con k:  10
# Entrenamiento: 67.4877%
# Testeo: 58.0433%.
# F1 score: 0.4121.
#
# con k:  11
# Entrenamiento: 67.3727%
# Testeo: 58.3716%.
# F1 score: 0.4734.
#
# con k:  12
# Entrenamiento: 67.0443%
# Testeo: 59.3565%.
# F1 score: 0.4274.
#
# con k:  13
# Entrenamiento: 66.7488%
# Testeo: 58.6999%.
# F1 score: 0.4736.
#
# con k:  14
# Entrenamiento: 66.1412%
# Testeo: 59.1596%.
# F1 score: 0.4176.
#
# con k:  15
# Entrenamiento: 66.4860%
# Testeo: 58.9626%.
# F1 score: 0.4690.
#
# con k:  16
# Entrenamiento: 65.5008%
# Testeo: 60.1445%.
# F1 score: 0.4290.
#
# con k:  17
# Entrenamiento: 65.3695%
# Testeo: 58.8969%.
# F1 score: 0.4640.
#
# con k:  18
# Entrenamiento: 64.9918%
# Testeo: 59.0282%.
# F1 score: 0.4124.
#
# con k:  19
# Entrenamiento: 65.1067%
# Testeo: 58.8313%.
# F1 score: 0.4618.
#
# con k:  20
# Entrenamiento: 64.8112%
# Testeo: 59.8162%.
# F1 score: 0.4259.
#
# con k:  21
# Entrenamiento: 64.8933%
# Testeo: 59.2252%.
# F1 score: 0.4576.
#
# con k:  22
# Entrenamiento: 65.1396%
# Testeo: 59.8818%.
# F1 score: 0.4241.
#
# con k:  23
# Entrenamiento: 65.1888%
# Testeo: 59.6192%.
# F1 score: 0.4581.
#
# con k:  24
# Entrenamiento: 64.9425%
# Testeo: 59.2909%.
# F1 score: 0.4140.
#
# con k:  25
# Entrenamiento: 65.5501%
# Testeo: 59.6192%.
# F1 score: 0.4524.
#
# con k:  26
# Entrenamiento: 64.6305%
# Testeo: 59.7505%.
# F1 score: 0.4179.
#
# con k:  27
# Entrenamiento: 64.6798%
# Testeo: 59.6192%.
# F1 score: 0.4464.
#
# con k:  28
# Entrenamiento: 64.7947%
# Testeo: 60.2101%.
# F1 score: 0.4229.
#
# con k:  29
# Entrenamiento: 64.6305%
# Testeo: 60.5384%.
# F1 score: 0.4571.
#
# con k:  30
# Entrenamiento: 63.8588%
# Testeo: 60.3414%.
# F1 score: 0.4237.
#
# con k:  31
# Entrenamiento: 63.8424%
# Testeo: 60.9980%.
# F1 score: 0.4600.
#
# con k:  32
# Entrenamiento: 63.6125%
# Testeo: 60.6041%.
# F1 score: 0.4242.
#
# con k:  33
# Entrenamiento: 63.7110%
# Testeo: 60.9980%.
# F1 score: 0.4600.
#
# con k:  34
# Entrenamiento: 63.3498%
# Testeo: 61.1293%.
# F1 score: 0.4330.
#
# con k:  35
# Entrenamiento: 63.6289%
# Testeo: 61.5233%.
# F1 score: 0.4574.
#
# con k:  36
# Entrenamiento: 62.9721%
# Testeo: 61.3920%.
# F1 score: 0.4302.
#
# con k:  37
# Entrenamiento: 63.2841%
# Testeo: 61.1950%.
# F1 score: 0.4492.
#
# con k:  38
# Entrenamiento: 62.7586%
# Testeo: 60.9324%.
# F1 score: 0.4218.
#
# con k:  39
# Entrenamiento: 62.9228%
# Testeo: 61.2607%.
# F1 score: 0.4517.

# %%
prueba.drop(columns="Kactual",inplace=True)

a= prueba.transform(lambda x: x*100)
plt.figure(figsize=(15, 15))

sns.heatmap(a, annot=True, fmt='.6f', linewidths=.5,cmap="Greens").set_ylim(40,-0.1)
# Out:
# (40, -0.1)

# %%
knn = KNeighborsClassifier(n_neighbors =3, metric="manhattan")

knn.fit(x_train, y_train)

res = predecir(knn,x_train,y_train,x_test,y_test)
# Out:
# Entrenamiento: 80.7882%
# Testeo: 61.6546%.
# F1 score: 0.5387.

# %% [markdown]
# ### Completo Features

# %%
to_predict.fillna("Nothing", inplace= True) 
len_(to_predict)

to_predict['keyword'] = to_predict['keyword'].str.replace('%',' ')
to_predict['keyword'] = to_predict['keyword'].str.replace('2','')
to_predict['keyword'] = to_predict['keyword'].str.replace('0','')

# %%
to_predict["Tiene_key_impor"] = (to_predict["keyword"] == "wreckage") | (to_predict["keyword"] == "debris")\
| (to_predict["keyword"] == "derailment") | (to_predict["keyword"] == "outbreak")\
| (to_predict["keyword"] == "oil split") | (to_predict["keyword"] == "typhoon") \
| (to_predict["keyword"] == "suicide bombing") | (to_predict["keyword"] == "suicide bomber")

to_predict["Tiene_key_no_impor"] = (to_predict["keyword"] == "aftershock")

# Categorical boolean mask
categorical_feature_mask = to_predict.dtypes==object
# filter categorical columns using mask and turn it into a list
categorical_cols = to_predict.columns[categorical_feature_mask].tolist()

le = LabelEncoder()

# apply le on categorical feature columns
to_predict[categorical_cols] = to_predict[categorical_cols].apply(lambda col: le.fit_transform(col))

# %%
to_predict["Tiene_key_impor"].value_counts()
# Out:
# False    3170
# True       93
# Name: Tiene_key_impor, dtype: int64

# %% [markdown]
# ### Resultado

# %%
#Resultado de test
knn = KNeighborsClassifier(n_neighbors = 3, metric="manhattan")

#Entreno con todo el dataset
knn.fit(x, y)

#Predigo la data
predict = knn.predict(to_predict)
predict
# Out:
# array([1, 0, 0, ..., 0, 0, 0], dtype=int64)

# %% [markdown]
# ### Guardo Submission

# %%
submission_output(to_predict, predict,"KNN v1.2 k=3.csv")
