# %%
import pandas as pd
from numpy import isnan
import seaborn as sns

sns.set(rc = {'figure.figsize':(20,10)})

# %%
grupos = pd.read_csv("grupos.csv", encoding = "ISO-8859-1")
leaderboard = pd.read_csv("nlp-getting-started-publicleaderboard.csv")
#leaderboard = leaderboard[ leaderboard['SubmissionDate'].gt('2020-06') ]

# %% [markdown]
# # Funciones

# %%
def seParecen(g,l,threshold):
    
    l = str(l)
    g = str(g)
    
    if len(g) > len(l):
        smaller = l
        larger = g
    else:
        smaller = g
        larger = l
        
    count = 0
    for i in range(len(smaller)):
        if g[i] == l[i]:
            count += 1
    
    return count/len(larger) >= threshold or smaller in larger

# %% [markdown]
# # Encontrando grupos que tienen un nombre parecido en kaggle a los de piazza
#
#     Esto se podria comentar por completo si tenemos el nombre exacto de cada grupo. De ser ese el caso se podria solucionar facil el filtrado con un simple merge

# %%
g_id = { g:i for i,g in enumerate(grupos['Nombre'].values)}
l_id = { l:i for i,l in enumerate(leaderboard['TeamName'].values)}

parecidos = {}
asignados = {}
for g in list(grupos['Nombre'].values):
    for l in list(leaderboard['TeamName'].values):
        
        if not (type(g) == type('') and type(l) == type('')):
            continue
            
        if seParecen(g,l,0.7):
            if not l in asignados:
                asignados[l] = g
                parecidos[g] = l
            
fuera = []
for g in g_id:
    if not g in parecidos:
        fuera.append(g)
        
for g in fuera:
    for l in list(leaderboard['TeamName'].values):
        
        if not (type(g) == type('') and type(l) == type('')):
            continue
            
        if seParecen(g,l,0.5):
            if not l in asignados:
                asignados[l] = g
                parecidos[g] = l
            
fuera = []
for g in g_id:
    if not g in parecidos:
        fuera.append(g)

# %% [markdown]
# # Filtrando

# %%
# En extra se agregan los grupos que no pudieron ser encontrados en la etapa anterior
#y que a ojo se encontraron en kaggle (AGREGAR TU NOMBRE DE GRUPO AHI)

extra = ['COVIDATOS' , 'fiuba_barros_gomez', 'Data Science Monsters']

cross = leaderboard[leaderboard['TeamName'].isin(list(parecidos.values()) + extra)]

# %% [markdown]
# # Leaderboard Orga de Datos

# %%
datos_leaderboard = cross.groupby('TeamName')['SubmissionDate'].max().to_frame().merge(cross, on = 'SubmissionDate')\
    .sort_values('Score', ascending = False).reset_index()[['TeamName','Score']]

teamName = 'DatUs' #pone tu grupo

your_team_score = datos_leaderboard[datos_leaderboard['TeamName'] == teamName]['Score'].values[0]
datos_leaderboard['relative'] = (datos_leaderboard['Score'] - your_team_score) * 100

datos_leaderboard
# Out:
#                         TeamName    Score  relative
# 0                   COVIgData-19  0.83113     0.889
# 1                      COVIDATOS  0.82715     0.491
# 2                          DatUs  0.82224     0.000
# 3             Grupo python fiuba  0.81703    -0.521
# 4                        DataSOS  0.81274    -0.950
# 5   El tio del marido de Pampita  0.81274    -0.950
# 6       Superficial Intelligence  0.81244    -0.980
# 7             fiuba_barros_gomez  0.81213    -1.011
# 8               Grupo Orga Datos  0.81060    -1.164
# 9                       Grupo 13  0.80999    -1.225
# 10                       Corona2  0.80845    -1.379
# 11         Data Science Monsters  0.80661    -1.563
# 12                    Grupo Rosa  0.80447    -1.777
# 13             Barbijo de Uranio  0.80202    -2.022
# 14                 Kung Fu Panda  0.80171    -2.053
# 15          El Cuarteto Imperial  0.79773    -2.451
# 16                  Equipo Cloud  0.79742    -2.482
# 17          Unidos por los datos  0.79528    -2.696
# 18                      Datastic  0.79466    -2.758
# 19                The Datalorian  0.79098    -3.126
# 20          El Cuarteto del Code  0.79037    -3.187
# 21                       Pyrañas  0.79037    -3.187
# 22                    Alpha Zero  0.78394    -3.830
# 23                        NamanG  0.78271    -3.953
# 24                     Datavid20  0.77781    -4.443
# 25     Grupo 33 - DataTravellers  0.77658    -4.566
# 26           Grupo 1 - King Data  0.77382    -4.842

# %% [markdown]
# # Podes ver el progreso de el team que quieras

# %%
teamName = 'DatUs' #pone tu grupo

v = sns.barplot(x = 'SubmissionDate', y = 'Score', data = leaderboard[ leaderboard['TeamName'] == teamName ])
v.set(ylim=(0.5, None))
for item in v.get_xticklabels():
        item.set_rotation(45)

# %% [markdown]
# # Cantidad de sumbits que significaron un nuevo record

# %%
cross.groupby('TeamName')['SubmissionDate'].count().sort_values(ascending = False)
# Out:
# TeamName
# DatUs                           22
# The Datalorian                  10
# Superficial Intelligence         9
# El Cuarteto del Code             9
# Barbijo de Uranio                8
# COVIDATOS                        8
# Datastic                         8
# Grupo 1 - King Data              8
# Unidos por los datos             8
# COVIgData-19                     7
# Corona2                          7
# Grupo 13                         7
# fiuba_barros_gomez               6
# El tio del marido de Pampita     6
# DataSOS                          5
# El Cuarteto Imperial             4
# Alpha Zero                       4
# Grupo 33 - DataTravellers        4
# Grupo Orga Datos                 4
# Grupo Rosa                       4
# Grupo python fiuba               4
# Pyrañas                          4
# Data Science Monsters            3
# Kung Fu Panda                    3
# Datavid20                        2
# NamanG                           2
# Equipo Cloud                     2
# Name: SubmissionDate, dtype: int64
