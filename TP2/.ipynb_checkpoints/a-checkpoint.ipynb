# %% [markdown]
# # PLOT: Top usuarios mas mencionados en tweets

# %%
#IMPORTS
# %run Functions.ipynb
import pandas as pd
import numpy as np
import random
import seaborn as sns
import matplotlib
import matplotlib.pyplot as plt
import warnings
import time
import category_encoders as ce

from sklearn.metrics import f1_score
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import OneHotEncoder 
from sklearn.preprocessing import Imputer

# %%
# Predictions de juguete
n =3263
predictions = np.arange(n)
for i in range(len(predictions)):
    predictions[i]=random.choice([0,1])

# %%
#CARGA DATA
train = pd.read_csv("Data/train.csv")
to_predict = pd.read_csv("Data/test.csv")

# %% [markdown]
# ### Completo cosas

# %%
train.drop(columns=["id"])
train.fillna("Nothing", inplace= True)
to_predict.fillna("Nothing", inplace= True)

# %% [markdown]
# ### Pongo algun Feature

# %%
train["Tiene_key_impor"] = (train["keyword"] == "wreckage") | (train["keyword"] == "debris") | (train["keyword"] == "derailment")


from sklearn.preprocessing import LabelEncoder

# Categorical boolean mask
categorical_feature_mask = train.dtypes==object
# filter categorical columns using mask and turn it into a list
categorical_cols = train.columns[categorical_feature_mask].tolist()

le = LabelEncoder()

# apply le on categorical feature columns
train[categorical_cols] = train[categorical_cols].apply(lambda col: le.fit_transform(col))

# %%
x = train[train.columns.drop("target")]
y = train['target']

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.20)

print(f"Original shapes: X={x.shape} y={y.shape}")
print(f"Train shapes: X={x_train.shape} y={y_train.shape}")
print(f"Test  shapes: X={x_test.shape}  y={y_test.shape}")
# Out:
# Original shapes: X=(7613, 5) y=(7613,)
# Train shapes: X=(6090, 5) y=(6090,)
# Test  shapes: X=(1523, 5)  y=(1523,)

# %% [markdown]
# ### Fit

# %%
k = list(range(2,40))
prueba = pd.DataFrame(k,index=k,columns=["Kactual"])

# %%
dists = [
"euclidean",
"manhattan",
"chebyshev"]


knn_best_distance(prueba,dists,x_train,y_train,x_test,y_test)
# Out:
# euclidean --------------------------
# con k:  2
# Entrenamiento: 80.4269%
# Testeo: 63.1648%.
# F1 score macro: 0.5809.
# F1 score micro: 0.6316.
# F1 score weighted: 0.6030.
#
# con k:  3
# Entrenamiento: 80.1149%
# Testeo: 60.9324%.
# F1 score macro: 0.5995.
# F1 score micro: 0.6093.
# F1 score weighted: 0.6090.
#
# con k:  4
# Entrenamiento: 74.4499%
# Testeo: 60.5384%.
# F1 score macro: 0.5694.
# F1 score micro: 0.6054.
# F1 score weighted: 0.5883.
#
# con k:  5
# Entrenamiento: 74.1872%
# Testeo: 59.4879%.
# F1 score macro: 0.5831.
# F1 score micro: 0.5949.
# F1 score weighted: 0.5937.
#
# con k:  6
# Entrenamiento: 71.5435%
# Testeo: 61.3920%.
# F1 score macro: 0.5768.
# F1 score micro: 0.6139.
# F1 score weighted: 0.5958.
#
# con k:  7
# Entrenamiento: 71.1494%
# Testeo: 60.1445%.
# F1 score macro: 0.5869.
# F1 score micro: 0.6014.
# F1 score weighted: 0.5986.
#
# con k:  8
# Entrenamiento: 69.7865%
# Testeo: 61.6546%.
# F1 score macro: 0.5811.
# F1 score micro: 0.6165.
# F1 score weighted: 0.5996.
#
# con k:  9
# Entrenamiento: 69.3760%
# Testeo: 59.8162%.
# F1 score macro: 0.5818.
# F1 score micro: 0.5982.
# F1 score weighted: 0.5944.
#
# con k:  10
# Entrenamiento: 68.7192%
# Testeo: 61.1293%.
# F1 score macro: 0.5771.
# F1 score micro: 0.6113.
# F1 score weighted: 0.5953.
#
# con k:  11
# Entrenamiento: 68.8013%
# Testeo: 60.4071%.
# F1 score macro: 0.5860.
# F1 score micro: 0.6041.
# F1 score weighted: 0.5991.
#
# con k:  12
# Entrenamiento: 68.3908%
# Testeo: 61.1293%.
# F1 score macro: 0.5785.
# F1 score micro: 0.6113.
# F1 score weighted: 0.5963.
#
# con k:  13
# Entrenamiento: 68.1609%
# Testeo: 60.5384%.
# F1 score macro: 0.5867.
# F1 score micro: 0.6054.
# F1 score weighted: 0.6000.
#
# con k:  14
# Entrenamiento: 66.9130%
# Testeo: 60.8011%.
# F1 score macro: 0.5751.
# F1 score micro: 0.6080.
# F1 score weighted: 0.5930.
#
# con k:  15
# Entrenamiento: 67.0608%
# Testeo: 60.2101%.
# F1 score macro: 0.5826.
# F1 score micro: 0.6021.
# F1 score weighted: 0.5963.
#
# con k:  16
# Entrenamiento: 66.4368%
# Testeo: 59.5535%.
# F1 score macro: 0.5614.
# F1 score micro: 0.5955.
# F1 score weighted: 0.5799.
#
# con k:  17
# Entrenamiento: 66.6667%
# Testeo: 59.7505%.
# F1 score macro: 0.5767.
# F1 score micro: 0.5975.
# F1 score weighted: 0.5909.
#
# con k:  18
# Entrenamiento: 65.7964%
# Testeo: 59.2252%.
# F1 score macro: 0.5590.
# F1 score micro: 0.5923.
# F1 score weighted: 0.5774.
#
# con k:  19
# Entrenamiento: 66.3218%
# Testeo: 59.1596%.
# F1 score macro: 0.5692.
# F1 score micro: 0.5916.
# F1 score weighted: 0.5841.
#
# con k:  20
# Entrenamiento: 65.4680%
# Testeo: 59.4222%.
# F1 score macro: 0.5589.
# F1 score micro: 0.5942.
# F1 score weighted: 0.5778.
#
# con k:  21
# Entrenamiento: 65.4187%
# Testeo: 59.3565%.
# F1 score macro: 0.5692.
# F1 score micro: 0.5936.
# F1 score weighted: 0.5848.
#
# con k:  22
# Entrenamiento: 64.8604%
# Testeo: 59.6848%.
# F1 score macro: 0.5592.
# F1 score micro: 0.5968.
# F1 score weighted: 0.5788.
#
# con k:  23
# Entrenamiento: 65.2709%
# Testeo: 58.9626%.
# F1 score macro: 0.5627.
# F1 score micro: 0.5896.
# F1 score weighted: 0.5791.
#
# con k:  24
# Entrenamiento: 64.6798%
# Testeo: 60.3414%.
# F1 score macro: 0.5668.
# F1 score micro: 0.6034.
# F1 score weighted: 0.5859.
#
# con k:  25
# Entrenamiento: 65.1888%
# Testeo: 60.1445%.
# F1 score macro: 0.5753.
# F1 score micro: 0.6014.
# F1 score weighted: 0.5913.
#
# con k:  26
# Entrenamiento: 64.4663%
# Testeo: 60.3414%.
# F1 score macro: 0.5685.
# F1 score micro: 0.6034.
# F1 score weighted: 0.5871.
#
# con k:  27
# Entrenamiento: 64.8604%
# Testeo: 60.1445%.
# F1 score macro: 0.5738.
# F1 score micro: 0.6014.
# F1 score weighted: 0.5903.
#
# con k:  28
# Entrenamiento: 64.5320%
# Testeo: 59.5535%.
# F1 score macro: 0.5582.
# F1 score micro: 0.5955.
# F1 score weighted: 0.5776.
#
# con k:  29
# Entrenamiento: 64.9918%
# Testeo: 59.3565%.
# F1 score macro: 0.5678.
# F1 score micro: 0.5936.
# F1 score weighted: 0.5838.
#
# con k:  30
# Entrenamiento: 64.3678%
# Testeo: 59.7505%.
# F1 score macro: 0.5605.
# F1 score micro: 0.5975.
# F1 score weighted: 0.5798.
#
# con k:  31
# Entrenamiento: 64.6634%
# Testeo: 59.6848%.
# F1 score macro: 0.5678.
# F1 score micro: 0.5968.
# F1 score weighted: 0.5848.
#
# con k:  32
# Entrenamiento: 63.9573%
# Testeo: 59.8818%.
# F1 score macro: 0.5597.
# F1 score micro: 0.5988.
# F1 score weighted: 0.5796.
#
# con k:  33
# Entrenamiento: 64.4171%
# Testeo: 59.7505%.
# F1 score macro: 0.5670.
# F1 score micro: 0.5975.
# F1 score weighted: 0.5845.
#
# con k:  34
# Entrenamiento: 64.1051%
# Testeo: 60.0131%.
# F1 score macro: 0.5619.
# F1 score micro: 0.6001.
# F1 score weighted: 0.5815.
#
# con k:  35
# Entrenamiento: 63.9080%
# Testeo: 59.7505%.
# F1 score macro: 0.5667.
# F1 score micro: 0.5975.
# F1 score weighted: 0.5842.
#
# con k:  36
# Entrenamiento: 63.7931%
# Testeo: 60.0788%.
# F1 score macro: 0.5613.
# F1 score micro: 0.6008.
# F1 score weighted: 0.5813.
#
# con k:  37
# Entrenamiento: 63.9737%
# Testeo: 60.0788%.
# F1 score macro: 0.5694.
# F1 score micro: 0.6008.
# F1 score weighted: 0.5871.
#
# con k:  38
# Entrenamiento: 63.5632%
# Testeo: 60.2101%.
# F1 score macro: 0.5639.
# F1 score micro: 0.6021.
# F1 score weighted: 0.5834.
#
# con k:  39
# Entrenamiento: 63.6946%
# Testeo: 60.4728%.
# F1 score macro: 0.5753.
# F1 score micro: 0.6047.
# F1 score weighted: 0.5922.
#
# manhattan --------------------------
# con k:  2
# Entrenamiento: 80.7718%
# Testeo: 63.0991%.
# F1 score macro: 0.5846.
# F1 score micro: 0.6310.
# F1 score weighted: 0.6056.
#
# con k:  3
# Entrenamiento: 80.7882%
# Testeo: 61.3263%.
# F1 score macro: 0.6031.
# F1 score micro: 0.6133.
# F1 score weighted: 0.6127.
#
# con k:  4
# Entrenamiento: 75.0575%
# Testeo: 61.7203%.
# F1 score macro: 0.5799.
# F1 score micro: 0.6172.
# F1 score weighted: 0.5989.
#
# con k:  5
# Entrenamiento: 74.8440%
# Testeo: 60.6697%.
# F1 score macro: 0.5958.
# F1 score micro: 0.6067.
# F1 score weighted: 0.6059.
#
# con k:  6
# Entrenamiento: 72.2003%
# Testeo: 61.5890%.
# F1 score macro: 0.5802.
# F1 score micro: 0.6159.
# F1 score weighted: 0.5988.
#
# con k:  7
# Entrenamiento: 72.1511%
# Testeo: 59.2909%.
# F1 score macro: 0.5792.
# F1 score micro: 0.5929.
# F1 score weighted: 0.5907.
#
# con k:  8
# Entrenamiento: 70.7061%
# Testeo: 62.0486%.
# F1 score macro: 0.5868.
# F1 score micro: 0.6205.
# F1 score weighted: 0.6047.
#
# con k:  9
# Entrenamiento: 70.4926%
# Testeo: 61.5890%.
# F1 score macro: 0.6002.
# F1 score micro: 0.6159.
# F1 score weighted: 0.6122.
#
# con k:  10
# Entrenamiento: 70.0164%
# Testeo: 61.5890%.
# F1 score macro: 0.5839.
# F1 score micro: 0.6159.
# F1 score weighted: 0.6014.
#
# con k:  11
# Entrenamiento: 69.9179%
# Testeo: 61.7203%.
# F1 score macro: 0.6000.
# F1 score micro: 0.6172.
# F1 score weighted: 0.6126.
#
# con k:  12
# Entrenamiento: 68.8506%
# Testeo: 61.9829%.
# F1 score macro: 0.5869.
# F1 score micro: 0.6198.
# F1 score weighted: 0.6046.
#
# con k:  13
# Entrenamiento: 68.7028%
# Testeo: 61.9173%.
# F1 score macro: 0.5998.
# F1 score micro: 0.6192.
# F1 score weighted: 0.6132.
#
# con k:  14
# Entrenamiento: 67.8654%
# Testeo: 62.3112%.
# F1 score macro: 0.5893.
# F1 score micro: 0.6231.
# F1 score weighted: 0.6072.
#
# con k:  15
# Entrenamiento: 67.8161%
# Testeo: 61.9829%.
# F1 score macro: 0.5996.
# F1 score micro: 0.6198.
# F1 score weighted: 0.6133.
#
# con k:  16
# Entrenamiento: 67.3071%
# Testeo: 62.4425%.
# F1 score macro: 0.5911.
# F1 score micro: 0.6244.
# F1 score weighted: 0.6088.
#
# con k:  17
# Entrenamiento: 67.2906%
# Testeo: 61.9173%.
# F1 score macro: 0.5986.
# F1 score micro: 0.6192.
# F1 score weighted: 0.6124.
#
# con k:  18
# Entrenamiento: 67.0936%
# Testeo: 62.3112%.
# F1 score macro: 0.5910.
# F1 score micro: 0.6231.
# F1 score weighted: 0.6084.
#
# con k:  19
# Entrenamiento: 67.2578%
# Testeo: 62.5082%.
# F1 score macro: 0.6021.
# F1 score micro: 0.6251.
# F1 score weighted: 0.6166.
#
# con k:  20
# Entrenamiento: 66.9458%
# Testeo: 62.2456%.
# F1 score macro: 0.5888.
# F1 score micro: 0.6225.
# F1 score weighted: 0.6066.
#
# con k:  21
# Entrenamiento: 67.1264%
# Testeo: 61.9173%.
# F1 score macro: 0.5946.
# F1 score micro: 0.6192.
# F1 score weighted: 0.6097.
#
# con k:  22
# Entrenamiento: 66.6174%
# Testeo: 62.3769%.
# F1 score macro: 0.5895.
# F1 score micro: 0.6238.
# F1 score weighted: 0.6075.
#
# con k:  23
# Entrenamiento: 66.9294%
# Testeo: 61.3263%.
# F1 score macro: 0.5882.
# F1 score micro: 0.6133.
# F1 score weighted: 0.6036.
#
# con k:  24
# Entrenamiento: 66.6338%
# Testeo: 62.1142%.
# F1 score macro: 0.5870.
# F1 score micro: 0.6211.
# F1 score weighted: 0.6050.
#
# con k:  25
# Entrenamiento: 66.6338%
# Testeo: 61.8516%.
# F1 score macro: 0.5917.
# F1 score micro: 0.6185.
# F1 score weighted: 0.6076.
#
# con k:  26
# Entrenamiento: 66.2562%
# Testeo: 61.5890%.
# F1 score macro: 0.5802.
# F1 score micro: 0.6159.
# F1 score weighted: 0.5988.
#
# con k:  27
# Entrenamiento: 66.5025%
# Testeo: 61.2607%.
# F1 score macro: 0.5850.
# F1 score micro: 0.6126.
# F1 score weighted: 0.6012.
#
# con k:  28
# Entrenamiento: 66.0263%
# Testeo: 61.3263%.
# F1 score macro: 0.5766.
# F1 score micro: 0.6133.
# F1 score weighted: 0.5955.
#
# con k:  29
# Entrenamiento: 66.2233%
# Testeo: 60.8011%.
# F1 score macro: 0.5802.
# F1 score micro: 0.6080.
# F1 score weighted: 0.5966.
#
# con k:  30
# Entrenamiento: 65.7635%
# Testeo: 60.8667%.
# F1 score macro: 0.5696.
# F1 score micro: 0.6087.
# F1 score weighted: 0.5892.
#
# con k:  31
# Entrenamiento: 65.8292%
# Testeo: 60.8667%.
# F1 score macro: 0.5804.
# F1 score micro: 0.6087.
# F1 score weighted: 0.5969.
#
# con k:  32
# Entrenamiento: 65.4187%
# Testeo: 61.1293%.
# F1 score macro: 0.5728.
# F1 score micro: 0.6113.
# F1 score weighted: 0.5923.
#
# con k:  33
# Entrenamiento: 65.2381%
# Testeo: 60.0788%.
# F1 score macro: 0.5707.
# F1 score micro: 0.6008.
# F1 score weighted: 0.5880.
#
# con k:  34
# Entrenamiento: 64.7455%
# Testeo: 60.8667%.
# F1 score macro: 0.5696.
# F1 score micro: 0.6087.
# F1 score weighted: 0.5892.
#
# con k:  35
# Entrenamiento: 64.7126%
# Testeo: 60.2758%.
# F1 score macro: 0.5727.
# F1 score micro: 0.6028.
# F1 score weighted: 0.5899.
#
# con k:  36
# Entrenamiento: 64.5484%
# Testeo: 61.1950%.
# F1 score macro: 0.5734.
# F1 score micro: 0.6120.
# F1 score weighted: 0.5928.
#
# con k:  37
# Entrenamiento: 64.4828%
# Testeo: 60.1445%.
# F1 score macro: 0.5696.
# F1 score micro: 0.6014.
# F1 score weighted: 0.5874.
#
# con k:  38
# Entrenamiento: 64.3021%
# Testeo: 61.0637%.
# F1 score macro: 0.5704.
# F1 score micro: 0.6106.
# F1 score weighted: 0.5904.
#
# con k:  39
# Entrenamiento: 63.8588%
# Testeo: 60.7354%.
# F1 score macro: 0.5759.
# F1 score micro: 0.6074.
# F1 score weighted: 0.5934.
#
# chebyshev --------------------------
# con k:  2
# Entrenamiento: 79.5074%
# Testeo: 62.6395%.
# F1 score macro: 0.5754.
# F1 score micro: 0.6264.
# F1 score weighted: 0.5977.
#
# con k:  3
# Entrenamiento: 79.6388%
# Testeo: 59.2909%.
# F1 score macro: 0.5814.
# F1 score micro: 0.5929.
# F1 score weighted: 0.5919.
#
# con k:  4
# Entrenamiento: 73.5796%
# Testeo: 60.0788%.
# F1 score macro: 0.5594.
# F1 score micro: 0.6008.
# F1 score weighted: 0.5799.
#
# con k:  5
# Entrenamiento: 73.7438%
# Testeo: 59.6192%.
# F1 score macro: 0.5816.
# F1 score micro: 0.5962.
# F1 score weighted: 0.5935.
#
# con k:  6
# Entrenamiento: 71.0509%
# Testeo: 62.5082%.
# F1 score macro: 0.5899.
# F1 score micro: 0.6251.
# F1 score weighted: 0.6081.
#
# con k:  7
# Entrenamiento: 70.5747%
# Testeo: 60.7354%.
# F1 score macro: 0.5929.
# F1 score micro: 0.6074.
# F1 score weighted: 0.6045.
#
# con k:  8
# Entrenamiento: 69.1133%
# Testeo: 61.3263%.
# F1 score macro: 0.5777.
# F1 score micro: 0.6133.
# F1 score weighted: 0.5963.
#
# con k:  9
# Entrenamiento: 68.7356%
# Testeo: 59.5535%.
# F1 score macro: 0.5798.
# F1 score micro: 0.5955.
# F1 score weighted: 0.5921.
#
# con k:  10
# Entrenamiento: 67.6519%
# Testeo: 60.1445%.
# F1 score macro: 0.5673.
# F1 score micro: 0.6014.
# F1 score weighted: 0.5857.
#
# con k:  11
# Entrenamiento: 67.7011%
# Testeo: 59.6192%.
# F1 score macro: 0.5778.
# F1 score micro: 0.5962.
# F1 score weighted: 0.5912.
#
# con k:  12
# Entrenamiento: 66.1576%
# Testeo: 58.9626%.
# F1 score macro: 0.5534.
# F1 score micro: 0.5896.
# F1 score weighted: 0.5727.
#
# con k:  13
# Entrenamiento: 66.3383%
# Testeo: 58.8969%.
# F1 score macro: 0.5667.
# F1 score micro: 0.5890.
# F1 score weighted: 0.5816.
#
# con k:  14
# Entrenamiento: 66.0591%
# Testeo: 58.4373%.
# F1 score macro: 0.5458.
# F1 score micro: 0.5844.
# F1 score weighted: 0.5659.
#
# con k:  15
# Entrenamiento: 66.3875%
# Testeo: 58.6343%.
# F1 score macro: 0.5634.
# F1 score micro: 0.5863.
# F1 score weighted: 0.5786.
#
# con k:  16
# Entrenamiento: 65.6814%
# Testeo: 58.4373%.
# F1 score macro: 0.5480.
# F1 score micro: 0.5844.
# F1 score weighted: 0.5675.
#
# con k:  17
# Entrenamiento: 65.8128%
# Testeo: 58.4373%.
# F1 score macro: 0.5604.
# F1 score micro: 0.5844.
# F1 score weighted: 0.5759.
#
# con k:  18
# Entrenamiento: 64.6962%
# Testeo: 57.9120%.
# F1 score macro: 0.5400.
# F1 score micro: 0.5791.
# F1 score weighted: 0.5604.
#
# con k:  19
# Entrenamiento: 65.1888%
# Testeo: 58.1747%.
# F1 score macro: 0.5543.
# F1 score micro: 0.5817.
# F1 score weighted: 0.5711.
#
# con k:  20
# Entrenamiento: 64.6470%
# Testeo: 59.3565%.
# F1 score macro: 0.5543.
# F1 score micro: 0.5936.
# F1 score weighted: 0.5744.
#
# con k:  21
# Entrenamiento: 64.9261%
# Testeo: 58.2403%.
# F1 score macro: 0.5558.
# F1 score micro: 0.5824.
# F1 score weighted: 0.5723.
#
# con k:  22
# Entrenamiento: 64.7455%
# Testeo: 59.5535%.
# F1 score macro: 0.5578.
# F1 score micro: 0.5955.
# F1 score weighted: 0.5774.
#
# con k:  23
# Entrenamiento: 64.4007%
# Testeo: 59.3565%.
# F1 score macro: 0.5669.
# F1 score micro: 0.5936.
# F1 score weighted: 0.5832.
#
# con k:  24
# Entrenamiento: 64.5484%
# Testeo: 59.6192%.
# F1 score macro: 0.5587.
# F1 score micro: 0.5962.
# F1 score weighted: 0.5782.
#
# con k:  25
# Entrenamiento: 64.6470%
# Testeo: 58.9626%.
# F1 score macro: 0.5624.
# F1 score micro: 0.5896.
# F1 score weighted: 0.5789.
#
# con k:  26
# Entrenamiento: 64.2693%
# Testeo: 59.4222%.
# F1 score macro: 0.5556.
# F1 score micro: 0.5942.
# F1 score weighted: 0.5755.
#
# con k:  27
# Entrenamiento: 64.2200%
# Testeo: 58.3716%.
# F1 score macro: 0.5553.
# F1 score micro: 0.5837.
# F1 score weighted: 0.5723.
#
# con k:  28
# Entrenamiento: 64.0887%
# Testeo: 59.1596%.
# F1 score macro: 0.5516.
# F1 score micro: 0.5916.
# F1 score weighted: 0.5719.
#
# con k:  29
# Entrenamiento: 64.3350%
# Testeo: 58.4373%.
# F1 score macro: 0.5546.
# F1 score micro: 0.5844.
# F1 score weighted: 0.5720.
#
# con k:  30
# Entrenamiento: 64.0066%
# Testeo: 58.5030%.
# F1 score macro: 0.5440.
# F1 score micro: 0.5850.
# F1 score weighted: 0.5647.
#
# con k:  31
# Entrenamiento: 63.8588%
# Testeo: 58.7656%.
# F1 score macro: 0.5573.
# F1 score micro: 0.5877.
# F1 score weighted: 0.5749.
#
# con k:  32
# Entrenamiento: 63.4154%
# Testeo: 59.6192%.
# F1 score macro: 0.5576.
# F1 score micro: 0.5962.
# F1 score weighted: 0.5774.
#
# con k:  33
# Entrenamiento: 63.5140%
# Testeo: 59.4222%.
# F1 score macro: 0.5640.
# F1 score micro: 0.5942.
# F1 score weighted: 0.5814.
#
# con k:  34
# Entrenamiento: 63.4154%
# Testeo: 59.7505%.
# F1 score macro: 0.5583.
# F1 score micro: 0.5975.
# F1 score weighted: 0.5782.
#
# con k:  35
# Entrenamiento: 63.3169%
# Testeo: 59.8818%.
# F1 score macro: 0.5688.
# F1 score micro: 0.5988.
# F1 score weighted: 0.5860.
#
# con k:  36
# Entrenamiento: 63.2512%
# Testeo: 60.5384%.
# F1 score macro: 0.5669.
# F1 score micro: 0.6054.
# F1 score weighted: 0.5865.
#
# con k:  37
# Entrenamiento: 63.1527%
# Testeo: 60.5384%.
# F1 score macro: 0.5742.
# F1 score micro: 0.6054.
# F1 score weighted: 0.5917.
#
# con k:  38
# Entrenamiento: 63.1034%
# Testeo: 59.8162%.
# F1 score macro: 0.5572.
# F1 score micro: 0.5982.
# F1 score weighted: 0.5777.
#
# con k:  39
# Entrenamiento: 63.2512%
# Testeo: 59.8162%.
# F1 score macro: 0.5663.
# F1 score micro: 0.5982.
# F1 score weighted: 0.5841.

# %%
prueba.drop(columns="Kactual",inplace=True)

a= prueba.transform(lambda x: x*100)
plt.figure(figsize=(15, 15))

sns.heatmap(a, annot=True, fmt='.6f', linewidths=.5,cmap="Greens").set_ylim(40,-0.1)
# Out:
# (40, -0.1)

# %%
knn = KNeighborsClassifier(n_neighbors =19, metric="manhattan")

knn.fit(x_train, y_train)

res = predecir(knn,x_train,y_train,x_test,y_test)
# Out:
# Entrenamiento: 67.2578%
# Testeo: 62.5082%.
# F1 score macro: 0.6021.
# F1 score micro: 0.6251.
# F1 score weighted: 0.6166.

# %% [markdown]
# ### Completo Features

# %%
to_predict["Tiene_key_impor"] = (to_predict["keyword"] == "wreckage") | (to_predict["keyword"] == "debris") | (to_predict["keyword"] == "derailment")\
| (to_predict["keyword"] == "debris") | (to_predict["keyword"] == "derailment")


# Categorical boolean mask
categorical_feature_mask = to_predict.dtypes==object
# filter categorical columns using mask and turn it into a list
categorical_cols = to_predict.columns[categorical_feature_mask].tolist()

le = LabelEncoder()

# apply le on categorical feature columns
to_predict[categorical_cols] = to_predict[categorical_cols].apply(lambda col: le.fit_transform(col))

# %% [markdown]
# ### Resultado

# %%
#Resultado de test
knn = KNeighborsClassifier(n_neighbors = 19, metric="manhattan")

#Entreno con todo el dataset
knn.fit(x, y)

#Predigo la data
predict = knn.predict(to_predict)
predict
# Out:
# array([0, 0, 1, ..., 0, 0, 0], dtype=int64)

# %% [markdown]
# ### Guardo Submission

# %%
submission_output(to_predict, predict,"KNN v1.02.csv")
