# %%
#IMPORTS
# %run ../datuslib.ipynb

# %%
#SETTINGS
pd.set_option("display.max_rows", None, "display.max_columns", None)

# %%
#CARGA DATA

A_tweets = pd.read_csv(generateAbsolutePath("train.csv", exists = True))

# %%
#USAR LOS MULTIPLES NOMBRES DE CADA PAIS QUE PROVEE EL GEONEMACACHE

#VOS TE INVENTASTE LOS ACRONIMOS DE LOS PAISES EN MUCHOS CASOS PERO ESTARIA BUENO USAR EL ISO Y EL ISO3

# %%
A_tweets2 = A_tweets.copy().dropna()

# %%
A_tweets2['parsed location'] = A_tweets2.apply(lambda row : getLocation(row['location']), axis = 1)

# %%
def haveAtLeastOneUnknown(parsedLocation):
    
    for component in parsedLocation:
        if component == UNKNOWN:
            return True
    return False

# %%
def haveAllUnknown(parsedLocation):
    
    for component in parsedLocation:
        if component != UNKNOWN:
            return False
    return True

# %%
fallos = A_tweets2[ A_tweets2.apply(lambda row : haveAllUnknown(row['parsed location']), axis = 1)][['location','parsed location']]

# %%
fallos.shape[0]
# Out:
# 1461

# %%
fallos
# Out:
#                                                location  \
# 37                                         World Wide!!
# 39                                       Paranaque City
# 40                                       Live On Webcam
# 42                                            milky way
# 48                                       Live On Webcam
# 55                                                  USA
# 58                                       hollywoodland
# 61                                     Inang Pamantasan
# 62                          Twitter Lockout in progress
# 67                                               CLVLND
# 81                                Your Sister's Bedroom
# 93                                               global
# 102                            Instagram - @heyimginog
# 103                                                 304
# 105                                                 304
# 107                                                 304
# ...
