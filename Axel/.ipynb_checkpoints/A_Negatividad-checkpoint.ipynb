# %%
#IMPORTS
# %run ../datuslib.ipynb

# %%
#SETTINGS
pd.set_option("display.max_rows", None, "display.max_columns", None)

# %%
#CARGA DATA

A_tweets = pd.read_csv(generateAbsolutePath("train.csv", exists = True))

# %%
#CARGA DE INTERNET PALBRAS NEGATIVAS

A_NEGATIVE_WORDS = getWordInListFromFile('negativeWords.txt')

# %%
#LAS SUGERENCIAS DE ENGLISH DICTIONARY NO SON TAN BUENAS

#QUIZAS NO SEA BUENA IDEA TRATAR DE FORZAR MUCHO A QUE SEAN PALABRAS EN INGLES

#FORZAR A QUE SEAN PALABRAS PARECIDAS Y NO TAN ENSUCIADAS

#ESTARIA BUENO PODER APLICAR UN FURTHER FILTRO CUANDO QUIERA DE QUITAR STOPWORDS Y FLAGS

#LAS STOPWORDS NO APORTAN NEGATIVIDAD

# %%
#CREO EL OBJETO CONTEXT
context = Context(data = A_tweets, load = 'contextPLUS')
# Out:
# Data loaded
# Texts loaded
# Texts Tokens loaded
# Clean Words loaded
# Token Clean Words map loaded
# Clean Words Token map loaded
# Contextual map loaded
# Disaster Frequency map loaded
# Total Frequency map loaded
# Negativity map loaded

# %%
A_tweets2 = A_tweets.copy().fillna(' ')

# %%
A_tweets2['negativity'] = A_tweets2.apply(lambda row : getTweetNegativity(row,context), axis = 1)

# %%
A_tweets2[['text','negativity']]
# Out:
#                                                  text  negativity
# 0   Our Deeds are the Reason of this #earthquake M...    5.914106
# 1              Forest fire near La Ronge Sask. Canada   10.833472
# 2   All residents asked to 'shelter in place' are ...   20.508717
# 3   13,000 people receive #wildfires evacuation or...    7.795143
# 4   Just got sent this photo from Ruby #Alaska as ...   12.209164
# 5   #RockyFire Update => California Hwy. 20 closed...   19.078710
# 6   #flood #disaster Heavy rain causes flash flood...   16.041705
# 7   I'm on top of the hill and I can see a fire in...    4.533643
# 8   There's an emergency evacuation happening now ...    6.009584
# 9   I'm afraid that the tornado is coming to our a...    3.505259
# 10        Three people died from the heat wave so far    5.735161
# 11  Haha South Tampa is getting flooded hah- WAIT ...   85.550345
# 12  #raining #flooding #Florida #TampaBay #Tampa 1...   10.682266
# 13            #Flood in Bago Myanmar #We arrived Bago   10.679028
# 14  Damage to school bus on 80 in multi car crash ...    5.660243
# 15                                     What's up man?    0.790215
# 16                                      I love fruits    0.807872
# 17                                   Summer is lovely    0.410761
# 18                                  My car is so fast    1.173768
# 19                       What a goooooooaaaaaal!!!!!!    0.000000
# 20                             this is ridiculous....    0.293478
# 21                                  London is cool ;)    1.577730
# 22                                        Love skiing    0.148881
# 23                              What a wonderful day!    0.314593
# 24                                           LOOOOOOL    0.482549
# 25                     No way...I can't eat that shit    1.815815
# 26                              Was in NYC last week!    1.612071
# 27                                 Love my girlfriend    0.148881
# 72  Reported motor vehicle accident in Curry on He...   55.846517
# 73                BigRigRadio Live Accident Awareness   10.835839
# 74  I-77 Mile Marker 31 South Mooresville  Iredell...   33.306599
# 75  RT @SleepJunkies: Sleeping pills double your r...   12.619840
# 76  'By accident' they knew what was gon happen ht...    5.575254
# 77  Traffic accident N CABRILLO HWY/MAGELLAN AV MI...   20.609313
# 78  I-77 Mile Marker 31 to 40 South Mooresville  I...   30.518743
# 79  the pastor was not in the scene of the acciden...   19.439379
# 80  mom: 'we didn't get home as fast as we wished'...   12.107872
# 81  I was in a horrible car accident this past Sun...   17.091658
# 82  Can wait to see how pissed Donnie is when I te...    8.037902
# 83  #TruckCrash Overturns On #FortWorth Interstate...   49.495801
# 84  Accident in #Ashville on US 23 SB before SR 75...   45.710756
# 85  Carolina accident: Motorcyclist Dies in I-540 ...   39.207813
# 86  FYI CAD:FYI: ;ACCIDENT PROPERTY DAMAGE;NHS;999...   37.507740
# 87  RT nAAYf: First accident in years. Turning ont...   61.785450
# 88  Accident left lane blocked in #Manchester on R...   46.083060
# 89    ;ACCIDENT PROPERTY DAMAGE; PINER RD/HORNDALE DR   15.517217
# 90     ???? it was an accident http://t.co/Oia5fxi4gM    6.192775
# 91  FYI CAD:FYI: ;ACCIDENT PROPERTY DAMAGE;WPD;160...   32.068977
# 92  8/6/2015@2:09 PM: TRAFFIC ACCIDENT NO INJURY a...   49.945340
# 93  Aashiqui Actress Anu Aggarwal On Her Near-Fata...   39.118566
# 94  Suffield Alberta Accident https://t.co/bPTmlF4P10   35.206929
# 95  9 Mile backup on I-77 South...accident blockin...   38.819608
# 96  Has an accident changed your life? We will hel...   14.148138
# 97  #BREAKING: there was a deadly motorcycle car a...   41.409309
# 98  @flowri were you marinading it or was it an ac...    4.122275
# 99  only had a car for not even a week and got in ...   11.656825

# %% [markdown]
# # PLOT: Sustantivos en ingles mas usados

# %%
#CREANDO UN DATAFRAME DE SUSTANTIVOS/FRECUENCIAS

A_nounsDF = getDataFrameOfFrecuencies('Palabras',context.cleanWords)

A_TOP_AMOUNT = 15
A_topNouns = A_nounsDF.head(A_TOP_AMOUNT)

# %%
barplot('Cantidad','Palabras', A_topNouns, xLabel = 'Frecuencia de uso', yLabel = 'Sustantivos',
        title = 'Sustantivos en ingles mas usadas en tweets, location o keywords', fontSize = 2)

# %% [markdown]
# # PLOT: Sustantivos en ingles negativos mas usadas
#
#     En este plot se esta usando como palabras negativas a plabras buscadas en internet

# %%
#CREANDO UN DATAFRAME DE SUSTANTIVOS NEGATIVOS/FRECUENCIAS

A_NegativeNounsDF = A_nounsDF[ A_nounsDF.apply(lambda row : isIn(row['Palabras'],A_NEGATIVE_WORDS), axis = 1)]

A_TOP_AMOUNT = 15
A_topNouns = A_NegativeNounsDF.head(A_TOP_AMOUNT)

# %%
barplot('Cantidad','Palabras', A_topNouns, xLabel = 'Frecuencia de uso', yLabel = 'Sustantivos', 
        title = 'Sustantivos en ingles negativos mas usadas en tweets, location o leywords', fontSize = 2)

# %% [markdown]
# # PLOT: Sustantivos en ingles mas usados en tweets de desastres
#
#     En este plot se esta usando como palabras negativas a plabras buscadas en internet

# %%
#OBTIENE TODAS LAS PALABRAS EN INGLES QUE FIGURAN EN CAMPO TEXT, KEYWORD y LOCATION DET TWEETS CON DESASTRE

A_tweetsDisaster = A_tweets[A_tweets['target'] == 1]

A_wordsDisasters = dicToDataFrame(context.disasterNounFrequency)
A_wordsDisasters['values'] = round(A_wordsDisasters['values'] * A_tweets.shape[0])

A_TOP_AMOUNT = 15
A_topWords = A_wordsDisasters.head(A_TOP_AMOUNT)

# %%
barplot('Cantidad','Palabras', A_topNouns, xLabel = 'Frecuencia de uso', yLabel = 'Sustantivos', 
        title = 'Sustantivos en ingles mas usadas en tweets de desastres, location o keywords', fontSize = 2)

# %% [markdown]
# # PLOT: Relacionando negatividad de los tweets y su longitud con si son desastres o no

# %%
#MOLDEANDO DATA
A_tweets1 = A_tweets.copy()

#(AGREGA) CAMPO DE TARGET CON NOMBRES MAS DETALLADOS QUE 1 o 0
A_tweets1['Categoria'] = A_tweets1.apply(lambda row : mapBinaryLabel(row['target'],
                                                                            ['Desastre','No Desastre']), axis = 1)
#(AGREGA) CAMPO DE LONGITUD DE TWEETS
A_tweets1['length'] = A_tweets1.apply(lambda row : len(row['text']), axis = 1)

#(AGREGA) CAMPO DE PALABRAS NEGATIVAS
A_tweets1['usa palabras negativas'] = A_tweets1.apply(lambda row : mapBinaryLabel(hasCertainWords(row['text'],A_NEGATIVE_WORDS),['Usa Palabras Negativas','No Usa Palabras Negativas']), axis = 1)

# %%
sns.set(font_scale = 1.7)
fg1 = sns.FacetGrid(A_tweets1, hue = 'usa palabras negativas',row = 'Categoria', height = 10, aspect = 2)
v = fg1.map(sns.distplot, "length", kde = False, bins = 50 )


for ax in v.axes.ravel():
    ax.legend()
    ax.set(xlabel = 'Longitud de Tweet', ylabel = 'Cantidad de Tweets')

# %% [markdown]
# # Analisis:
#
# Parece que en el caso de los desastres no parece haber diferencia en los tweets en cuanto a si usa o no palabras negativas (salvo en aquellos de longitud media que parecen tener un pequeña tendencia a ser mas neutros que negativos)
#
# Por otro lado, en el caso de los no desastres, es claro que predominan en cualquier longitud de tweet (salvo en los largos) los tweets neutros

# %% [markdown]
# # FEATURE: Agregando escala de negatividad de un tweet (0 es nada y 1 es pura)
