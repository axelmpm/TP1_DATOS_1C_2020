# %%
#IMPORTS
# %run ../datuslib.ipynb

# %%
#SETTINGS
pd.set_option("display.max_rows", None, "display.max_columns", None)

# %%
#CARGA DATA

A_tweets = pd.read_csv(generateAbsolutePath("train.csv", exists = True))

# %%
# VER PORQUE MAPEA MAL LOS NOMBRES SI LA INFO LA TIENE

# HACER QUE DEVUELVA EL CONTINENTE EN DONDE DEBE EN VEZ DE DEVOLVER EL PAIS OTRA VEZ 
# (pre hacer mapping entre paises y continentes)

# PORQUE HAY PAISES QUE PONE NADA QUE VER

# HACER QUE USE LOS ACRONIMOS DE PAISES PARA ENCONTRAR PAISES

# PORQUE PONE COMO UNKOWN COSAS QUE SABE

# %%
A_tweets2 = A_tweets.copy().head(500)

# %%
A_tweets2['parsed location'] = A_tweets2.apply(lambda row : getLocation(row['location']), axis = 1)

# %%
A_tweets2[['location','parsed location']]
# Out:
#                            location  \
# 0                               NaN
# 1                               NaN
# 2                               NaN
# 3                               NaN
# 4                               NaN
# 5                               NaN
# 6                               NaN
# 7                               NaN
# 8                               NaN
# 9                               NaN
# 10                              NaN
# 11                              NaN
# 12                              NaN
# 13                              NaN
# 14                              NaN
# 15                              NaN
# 16                              NaN
# 17                              NaN
# 18                              NaN
# 19                              NaN
# 20                              NaN
# 21                              NaN
# 22                              NaN
# 23                              NaN
# 24                              NaN
# ...
