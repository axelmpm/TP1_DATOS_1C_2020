# %%
#IMPORTS
# %run ../datuslib.ipynb

# %%
#SETTINGS
pd.set_option("display.max_rows", None, "display.max_columns", None)

# %%
#CARGA DATA

A_tweets = pd.read_csv(generateAbsolutePath("train.csv", exists = True))

# %%
A_tweets2 = A_tweets.copy().head(100)

# %%
A_tweets2['parsed location'] = A_tweets2.apply(lambda row : getLocation(str(row['location'])), axis = 1)

# %%
A_tweets2['location']
# Out:
#      id   keyword                       location  \
# 0     1       NaN                            NaN
# 1     4       NaN                            NaN
# 2     5       NaN                            NaN
# 3     6       NaN                            NaN
# 4     7       NaN                            NaN
# 5     8       NaN                            NaN
# 6    10       NaN                            NaN
# 7    13       NaN                            NaN
# 8    14       NaN                            NaN
# 9    15       NaN                            NaN
# 10   16       NaN                            NaN
# 11   17       NaN                            NaN
# 12   18       NaN                            NaN
# 13   19       NaN                            NaN
# 14   20       NaN                            NaN
# 15   23       NaN                            NaN
# 16   24       NaN                            NaN
# 17   25       NaN                            NaN
# ...
