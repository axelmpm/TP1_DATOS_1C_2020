# %%
#IMPORTS
# %run ../datuslib.ipynb

# %%
#SETTINGS
pd.set_option("display.max_rows", None, "display.max_columns", None)

# %%
#CARGA DATA

A_tweets = pd.read_csv(generateAbsolutePath("train.csv", exists = True))

# %%
A_tweets2 = A_tweets.copy().head(500)

# %%
A_tweets2['parsed location'] = A_tweets2.apply(lambda row : getLocation(str(row['location'])), axis = 1)

# %%
A_tweets2[['location', 'parsed location']]
# Out:
#                            location                    parsed location
# 0                               NaN          (__UNKNOWN, Europe, None)
# 1                               NaN          (__UNKNOWN, Europe, None)
# 2                               NaN          (__UNKNOWN, Europe, None)
# 3                               NaN          (__UNKNOWN, Europe, None)
# 4                               NaN          (__UNKNOWN, Europe, None)
# 5                               NaN          (__UNKNOWN, Europe, None)
# 6                               NaN          (__UNKNOWN, Europe, None)
# 7                               NaN          (__UNKNOWN, Europe, None)
# 8                               NaN          (__UNKNOWN, Europe, None)
# 9                               NaN          (__UNKNOWN, Europe, None)
# 10                              NaN          (__UNKNOWN, Europe, None)
# 11                              NaN          (__UNKNOWN, Europe, None)
# 12                              NaN          (__UNKNOWN, Europe, None)
# 13                              NaN          (__UNKNOWN, Europe, None)
# 14                              NaN          (__UNKNOWN, Europe, None)
# 15                              NaN          (__UNKNOWN, Europe, None)
# 16                              NaN          (__UNKNOWN, Europe, None)
# 17                              NaN          (__UNKNOWN, Europe, None)
# 18                              NaN          (__UNKNOWN, Europe, None)
# 19                              NaN          (__UNKNOWN, Europe, None)
# 20                              NaN          (__UNKNOWN, Europe, None)
# 21                              NaN          (__UNKNOWN, Europe, None)
# 22                              NaN          (__UNKNOWN, Europe, None)
# 23                              NaN          (__UNKNOWN, Europe, None)
# 24                              NaN          (__UNKNOWN, Europe, None)
# 25                              NaN          (__UNKNOWN, Europe, None)
# 26                              NaN          (__UNKNOWN, Europe, None)
# 27                              NaN          (__UNKNOWN, Europe, None)
# 28                              NaN          (__UNKNOWN, Europe, None)
# 29                              NaN          (__UNKNOWN, Europe, None)
# 30                              NaN          (__UNKNOWN, Europe, None)
# 31                       Birmingham          (__UNKNOWN, Europe, None)
# 32    Est. September 2012 - Bristol          (__UNKNOWN, Europe, None)
# 33                           AFRICA          (__UNKNOWN, Europe, None)
# 34                 Philadelphia, PA          (__UNKNOWN, Europe, None)
# 35                       London, UK          (__UNKNOWN, Europe, None)
# 36                         Pretoria          (__UNKNOWN, Europe, None)
# 37                     World Wide!!          (__UNKNOWN, Europe, None)
# 38                              NaN          (__UNKNOWN, Europe, None)
# 39                   Paranaque City          (__UNKNOWN, Europe, None)
# 40                   Live On Webcam          (__UNKNOWN, Europe, None)
# 41                              NaN          (__UNKNOWN, Europe, None)
# 42                        milky way          (__UNKNOWN, Europe, None)
# 43                              NaN          (__UNKNOWN, Europe, None)
# 44                              NaN          (__UNKNOWN, Europe, None)
# 45                              NaN          (__UNKNOWN, Europe, None)
# 46        GREENSBORO,NORTH CAROLINA          (__UNKNOWN, Europe, None)
# 47                              NaN          (__UNKNOWN, Europe, None)
# 48                   Live On Webcam          (__UNKNOWN, Europe, None)
# 49                         England.          (__UNKNOWN, Europe, None)
# 50         Sheffield Township, Ohio          (__UNKNOWN, Europe, None)
# 51                            India          (__UNKNOWN, Europe, None)
# 52                         Barbados          (__UNKNOWN, Europe, None)
# 53                          Anaheim          (__UNKNOWN, Europe, None)
# 54                            Abuja          (__UNKNOWN, Europe, None)
# 55                              USA          (__UNKNOWN, Europe, None)
# 56                     South Africa          (__UNKNOWN, Europe, None)
# 57                Sao Paulo, Brazil          (__UNKNOWN, Europe, None)
# 58                   hollywoodland           (__UNKNOWN, Europe, None)
# 59     Edmonton, Alberta - Treaty 6          (__UNKNOWN, Europe, None)
# 60                              NaN          (__UNKNOWN, Europe, None)
# 61                 Inang Pamantasan          (__UNKNOWN, Europe, None)
# 62      Twitter Lockout in progress          (__UNKNOWN, Europe, None)
# 63                      Concord, CA          (__UNKNOWN, Europe, None)
# 64                      Calgary, AB          (__UNKNOWN, Europe, None)
# 65                       Birmingham          (__UNKNOWN, Europe, None)
# 66                    San Francisco          (__UNKNOWN, Europe, None)
# 67                           CLVLND          (__UNKNOWN, Europe, None)
# 68                    Nashville, TN          (__UNKNOWN, Europe, None)
# 69                  Santa Clara, CA          (__UNKNOWN, Europe, None)
# 70                               UK          (__UNKNOWN, Europe, None)
# 71                    St. Louis, MO          (__UNKNOWN, Europe, None)
# 72           Walker County, Alabama          (__UNKNOWN, Europe, None)
# 73                        Australia          (__UNKNOWN, Europe, None)
# 74                   North Carolina          (__UNKNOWN, Europe, None)
# 75                              NaN          (__UNKNOWN, Europe, None)
# 76                    Norf Carolina          (__UNKNOWN, Europe, None)
# 77             San Mateo County, CA          (__UNKNOWN, Europe, None)
# 78                   North Carolina          (__UNKNOWN, Europe, None)
# 79                     Njoro, Kenya          (__UNKNOWN, Europe, None)
# 80                              NaN          (__UNKNOWN, Europe, None)
# 81            Your Sister's Bedroom          (__UNKNOWN, Europe, None)
# 82                              NaN          (__UNKNOWN, Europe, None)
# 83                    Arlington, TX          (__UNKNOWN, Europe, None)
# 84             South Bloomfield, OH          (__UNKNOWN, Europe, None)
# 85                              NaN          (__UNKNOWN, Europe, None)
# 86           New Hanover County, NC          (__UNKNOWN, Europe, None)
# 87                         Maldives          (__UNKNOWN, Europe, None)
# 88                   Manchester, NH          (__UNKNOWN, Europe, None)
# 89                   Wilmington, NC          (__UNKNOWN, Europe, None)
# 90                              NaN          (__UNKNOWN, Europe, None)
# 91           New Hanover County, NC          (__UNKNOWN, Europe, None)
# 92                              NaN          (__UNKNOWN, Europe, None)
# 93                           global          (__UNKNOWN, Europe, None)
# 94        Alberta | Sask. | Montana          (__UNKNOWN, Europe, None)
# 95                        Charlotte          (__UNKNOWN, Europe, None)
# 96                  Baton Rouge, LA          (__UNKNOWN, Europe, None)
# 97                   Hagerstown, MD          (__UNKNOWN, Europe, None)
# 98             Gloucestershire , UK          (__UNKNOWN, Europe, None)
# 99                              NaN          (__UNKNOWN, Europe, None)
# 100                              UK          (__UNKNOWN, Europe, None)
# 101                  Nairobi, Kenya          (__UNKNOWN, Europe, None)
# 102        Instagram - @heyimginog           (__UNKNOWN, Europe, None)
# 103                             304  (__UNKNOWN, __UNKNOWN, __UNKNOWN)
# 104                     Switzerland          (__UNKNOWN, Europe, None)
# 105                             304  (__UNKNOWN, __UNKNOWN, __UNKNOWN)
# 106                              US          (__UNKNOWN, Europe, None)
# 107                             304  (__UNKNOWN, __UNKNOWN, __UNKNOWN)
# 108        Instagram - @heyimginog           (__UNKNOWN, Europe, None)
# 109                             304  (__UNKNOWN, __UNKNOWN, __UNKNOWN)
# 110                             NaN          (__UNKNOWN, Europe, None)
# 111        Somewhere Only We Know ?          (__UNKNOWN, Europe, None)
# 112                             NaN          (__UNKNOWN, Europe, None)
# 113                         Belgium          (__UNKNOWN, Europe, None)
# 114                     Switzerland          (__UNKNOWN, Europe, None)
# 115                              US          (__UNKNOWN, Europe, None)
# 116                             NaN          (__UNKNOWN, Europe, None)
# 117                       dope show          (__UNKNOWN, Europe, None)
# 118                     Switzerland          (__UNKNOWN, Europe, None)
# 119                     Switzerland          (__UNKNOWN, Europe, None)
# 120                  Oshawa, Canada          (__UNKNOWN, Europe, None)
# 121               Baker City Oregon          (__UNKNOWN, Europe, None)
# 122                             NaN          (__UNKNOWN, Europe, None)
# 123                             NaN          (__UNKNOWN, Europe, None)
# 124                   United States          (__UNKNOWN, Europe, None)
# 125                             304  (__UNKNOWN, __UNKNOWN, __UNKNOWN)
# 126                             304  (__UNKNOWN, __UNKNOWN, __UNKNOWN)
# 127                  marysville ca           (__UNKNOWN, Europe, None)
# 128                             304  (__UNKNOWN, __UNKNOWN, __UNKNOWN)
# 129               Hermosa Beach, CA          (__UNKNOWN, Europe, None)
# 130                             NaN          (__UNKNOWN, Europe, None)
# 131                             NaN          (__UNKNOWN, Europe, None)
# 132                             NaN          (__UNKNOWN, Europe, None)
# 133                             304  (__UNKNOWN, __UNKNOWN, __UNKNOWN)
# 134                             304  (__UNKNOWN, __UNKNOWN, __UNKNOWN)
# 135                             NaN          (__UNKNOWN, Europe, None)
# 136           19.600858, -99.047821  (__UNKNOWN, __UNKNOWN, __UNKNOWN)
# 137                    Pennsylvania          (__UNKNOWN, Europe, None)
# 138            Salt Lake City, Utah          (__UNKNOWN, Europe, None)
# 139                   Palo Alto, CA          (__UNKNOWN, Europe, None)
# 140                             NaN          (__UNKNOWN, Europe, None)
# 141         Spain but Opa-Locka, FL          (__UNKNOWN, Europe, None)
# 142                   Jaipur, India          (__UNKNOWN, Europe, None)
# 143       Hyderabad Telangana INDIA          (__UNKNOWN, Europe, None)
# 144               Eagle Pass, Texas          (__UNKNOWN, Europe, None)
# 145                       bangalore          (__UNKNOWN, Europe, None)
# 146        Financial News and Views          (__UNKNOWN, Europe, None)
# 147                             NaN          (__UNKNOWN, Europe, None)
# 148                       Indonesia          (__UNKNOWN, Europe, None)
# 149         y(our) boyfriends legs           (__UNKNOWN, Europe, None)
# 150                 New Mexico, USA          (__UNKNOWN, Europe, None)
# 151             Somewhere Out There          (__UNKNOWN, Europe, None)
# 152                             NaN          (__UNKNOWN, Europe, None)
# 153                    Mumbai india          (__UNKNOWN, Europe, None)
# 154                       sri lanka          (__UNKNOWN, Europe, None)
# 155              Not a U.S resident          (__UNKNOWN, Europe, None)
# 156                             NaN          (__UNKNOWN, Europe, None)
# 157               Lehigh Valley, PA          (__UNKNOWN, Europe, None)
# 158                          Canada          (__UNKNOWN, Europe, None)
# 159                             NaN          (__UNKNOWN, Europe, None)
# 160                        Thrissur          (__UNKNOWN, Europe, None)
# 161                       Havenford          (__UNKNOWN, Europe, None)
# 162                           India          (__UNKNOWN, Europe, None)
# 163                              92  (__UNKNOWN, __UNKNOWN, __UNKNOWN)
# 164                             NaN          (__UNKNOWN, Europe, None)
# 165                          Israel          (__UNKNOWN, Europe, None)
# 166       Fashion Heaven. IG: TMId_          (__UNKNOWN, Europe, None)
# 167               San Francisco, CA          (__UNKNOWN, Europe, None)
# 168                           italy          (__UNKNOWN, Europe, None)
# 169                             nyc          (__UNKNOWN, Europe, None)
# 170                         Toronto          (__UNKNOWN, Europe, None)
# 171                             NaN          (__UNKNOWN, Europe, None)
# 172                         Jackson          (__UNKNOWN, Europe, None)
# 173            New York / Worldwide          (__UNKNOWN, Europe, None)
# 174                             NaN          (__UNKNOWN, Europe, None)
# 175                 New Orleans, LA          (__UNKNOWN, Europe, None)
# 176                      West Wales          (__UNKNOWN, Europe, None)
# 177                             NaN          (__UNKNOWN, Europe, None)
# 178    Happily Married with 2 kids           (__UNKNOWN, Europe, None)
# 179                   Cambridge, MA          (__UNKNOWN, Europe, None)
# 180                        Arizona           (__UNKNOWN, Europe, None)
# 181                          Mumbai          (__UNKNOWN, Europe, None)
# 182                             NaN          (__UNKNOWN, Europe, None)
# 183                       Amsterdam          (__UNKNOWN, Europe, None)
# 184                Swindon,England           (__UNKNOWN, Europe, None)
# 185                             NaN          (__UNKNOWN, Europe, None)
# 186    Happily Married with 2 kids           (__UNKNOWN, Europe, None)
# 187                             NaN          (__UNKNOWN, Europe, None)
# 188                Williamstown, VT          (__UNKNOWN, Europe, None)
# 189             North Carolina, USA          (__UNKNOWN, Europe, None)
# 190                             NaN          (__UNKNOWN, Europe, None)
# 191                         Karachi          (__UNKNOWN, Europe, None)
# 192    Happily Married with 2 kids           (__UNKNOWN, Europe, None)
# 193    Happily Married with 2 kids           (__UNKNOWN, Europe, None)
# 194               Loveland Colorado          (__UNKNOWN, Europe, None)
# 195             || c h i c a g o ||          (__UNKNOWN, Europe, None)
# 196                             NaN          (__UNKNOWN, Europe, None)
# 197                           L. A.          (__UNKNOWN, Europe, None)
# 198                             NaN          (__UNKNOWN, Europe, None)
# 199                          Canada          (__UNKNOWN, Europe, None)
# 200       VISIT MY YOUTUBE CHANNEL.          (__UNKNOWN, Europe, None)
# 201                       Lexington          (__UNKNOWN, Europe, None)
# 202                             NaN          (__UNKNOWN, Europe, None)
# 203                             USA          (__UNKNOWN, Europe, None)
# 204               Hannover, Germany          (__UNKNOWN, Europe, None)
# 205                             NaN          (__UNKNOWN, Europe, None)
# 206                             NaN          (__UNKNOWN, Europe, None)
# 207                           Playa          (__UNKNOWN, Europe, None)
# 208                    Davidson, NC          (__UNKNOWN, Europe, None)
# 209                   Higher Places          (__UNKNOWN, Europe, None)
# 210                   Horsemind, MI          (__UNKNOWN, Europe, None)
# 211                    New York, NY          (__UNKNOWN, Europe, None)
# 212                        Boksburg          (__UNKNOWN, Europe, None)
# 213                             NaN          (__UNKNOWN, Europe, None)
# 214                             NaN          (__UNKNOWN, Europe, None)
# 215                             NaN          (__UNKNOWN, Europe, None)
# 216      V-RP @OZRP_ ?MV, AU, R18+?          (__UNKNOWN, Europe, None)
# 217          Greater Manchester, UK          (__UNKNOWN, Europe, None)
# 218                          Boston          (__UNKNOWN, Europe, None)
# 219                             NaN          (__UNKNOWN, Europe, None)
# 220                             NaN          (__UNKNOWN, Europe, None)
# 221              The Canopy Kingdom          (__UNKNOWN, Europe, None)
# 222                             NaN          (__UNKNOWN, Europe, None)
# 223                             USA          (__UNKNOWN, Europe, None)
# 224                             NaN          (__UNKNOWN, Europe, None)
# 225                             NaN          (__UNKNOWN, Europe, None)
# 226             the own zone layer           (__UNKNOWN, Europe, None)
# 227                          London          (__UNKNOWN, Europe, None)
# 228                    Trancy Manor          (__UNKNOWN, Europe, None)
# 229                             NaN          (__UNKNOWN, Europe, None)
# 230                        South 37          (__UNKNOWN, Europe, None)
# 231                             NaN          (__UNKNOWN, Europe, None)
# 232            West Lancashire, UK.          (__UNKNOWN, Europe, None)
# 233                              PA          (__UNKNOWN, Europe, None)
# 234                             NaN          (__UNKNOWN, Europe, None)
# 235      Û¢ Views From The Six Û¢          (__UNKNOWN, Europe, None)
# 236                             NaN          (__UNKNOWN, Europe, None)
# 237           University of Toronto          (__UNKNOWN, Europe, None)
# 238                             NaN          (__UNKNOWN, Europe, None)
# 239                  Swaning Around          (__UNKNOWN, Europe, None)
# 240                             NaN          (__UNKNOWN, Europe, None)
# 241                          London          (__UNKNOWN, Europe, None)
# 242                       Albany/NY          (__UNKNOWN, Europe, None)
# 243                 California, USA          (__UNKNOWN, Europe, None)
# 244                             NaN          (__UNKNOWN, Europe, None)
# 245                             NaN          (__UNKNOWN, Europe, None)
# 246                             NaN          (__UNKNOWN, Europe, None)
# 247                   Wild Wild Web          (__UNKNOWN, Europe, None)
# 248                 Subconscious LA          (__UNKNOWN, Europe, None)
# 249                           Spain          (__UNKNOWN, Europe, None)
# 250                             NaN          (__UNKNOWN, Europe, None)
# 251   CA physically- Boston Strong?          (__UNKNOWN, Europe, None)
# 252            Yeezy Taught Me , NV          (__UNKNOWN, Europe, None)
# 253                             NaN          (__UNKNOWN, Europe, None)
# 254   CA physically- Boston Strong?          (__UNKNOWN, Europe, None)
# 255                   United States          (__UNKNOWN, Europe, None)
# 256                             NaN          (__UNKNOWN, Europe, None)
# 257                             NaN          (__UNKNOWN, Europe, None)
# 258                   Rock Hill, SC          (__UNKNOWN, Europe, None)
# 259                    Coolidge, AZ          (__UNKNOWN, Europe, None)
# 260               Republic of Texas          (__UNKNOWN, Europe, None)
# 261                             NaN          (__UNKNOWN, Europe, None)
# 262                             NaN          (__UNKNOWN, Europe, None)
# 263                     Phoenix, AZ          (__UNKNOWN, Europe, None)
# 264             Ljubljana, Slovenia          (__UNKNOWN, Europe, None)
# 265                     Connecticut          (__UNKNOWN, Europe, None)
# 266               Tacoma,Washington          (__UNKNOWN, Europe, None)
# 267                             NaN          (__UNKNOWN, Europe, None)
# 268                             NaN          (__UNKNOWN, Europe, None)
# 269                 Subconscious LA          (__UNKNOWN, Europe, None)
# 270    BIG D  HOUSTON/BOSTON/DENVER          (__UNKNOWN, Europe, None)
# 271                    Chandler, AZ          (__UNKNOWN, Europe, None)
# 272                        ColoRADo          (__UNKNOWN, Europe, None)
# 273                         sindria          (__UNKNOWN, Europe, None)
# 274                             NaN          (__UNKNOWN, Europe, None)
# 275                             NaN          (__UNKNOWN, Europe, None)
# 276                           Texas          (__UNKNOWN, Europe, None)
# 277              Elk Grove, CA, USA          (__UNKNOWN, Europe, None)
# 278                           Texas          (__UNKNOWN, Europe, None)
# 279                             NaN          (__UNKNOWN, Europe, None)
# 280                       The Shire          (__UNKNOWN, Europe, None)
# 281                      Austin, TX          (__UNKNOWN, Europe, None)
# 282                         Oakland          (__UNKNOWN, Europe, None)
# 283                             NaN          (__UNKNOWN, Europe, None)
# 284                             NaN          (__UNKNOWN, Europe, None)
# 285                     Albuquerque          (__UNKNOWN, Europe, None)
# 286                             NaN          (__UNKNOWN, Europe, None)
# 287         Buenos Aires, Argentina          (__UNKNOWN, Europe, None)
# 288                             NaN          (__UNKNOWN, Europe, None)
# 289                             NaN          (__UNKNOWN, Europe, None)
# 290             San Antonio-ish, TX          (__UNKNOWN, Europe, None)
# 291                   San Francisco          (__UNKNOWN, Europe, None)
# 292                     Oregon, USA          (__UNKNOWN, Europe, None)
# 293                   Harlingen, TX          (__UNKNOWN, Europe, None)
# 294                      Buffalo NY          (__UNKNOWN, Europe, None)
# 295                             NaN          (__UNKNOWN, Europe, None)
# 296                             NaN          (__UNKNOWN, Europe, None)
# 297                             NaN          (__UNKNOWN, Europe, None)
# 298                       Las Vegas          (__UNKNOWN, Europe, None)
# 299                             NaN          (__UNKNOWN, Europe, None)
# 300                             NaN          (__UNKNOWN, Europe, None)
# 301                             NaN          (__UNKNOWN, Europe, None)
# 302                           Tokyo          (__UNKNOWN, Europe, None)
# 303                             NaN          (__UNKNOWN, Europe, None)
# 304       California, United States          (__UNKNOWN, Europe, None)
# 305       California, United States          (__UNKNOWN, Europe, None)
# 306                #FLIGHTCITY UK            (__UNKNOWN, Europe, None)
# 307                             NaN          (__UNKNOWN, Europe, None)
# 308                             NaN          (__UNKNOWN, Europe, None)
# 309    Alphen aan den Rijn, Holland          (__UNKNOWN, Europe, None)
# 310                             NaN          (__UNKNOWN, Europe, None)
# 311                   Wrigley Field          (__UNKNOWN, Europe, None)
# 312                             NaN          (__UNKNOWN, Europe, None)
# 313         probably the strip club          (__UNKNOWN, Europe, None)
# 314                          Canada          (__UNKNOWN, Europe, None)
# 315                         England          (__UNKNOWN, Europe, None)
# 316                             USA          (__UNKNOWN, Europe, None)
# 317       California, United States          (__UNKNOWN, Europe, None)
# 318                             NaN          (__UNKNOWN, Europe, None)
# 319       California, United States          (__UNKNOWN, Europe, None)
# 320                   New York City          (__UNKNOWN, Europe, None)
# 321                  Here And There          (__UNKNOWN, Europe, None)
# 322         Rotterdam, Zuid-Holland          (__UNKNOWN, Europe, None)
# 323                      Derry, 17           (__UNKNOWN, Europe, None)
# 324            Nowhere. Everywhere.          (__UNKNOWN, Europe, None)
# 325                    Florida, USA          (__UNKNOWN, Europe, None)
# 326                       Worldwide          (__UNKNOWN, Europe, None)
# 327                             NaN          (__UNKNOWN, Europe, None)
# 328            Nowhere. Everywhere.          (__UNKNOWN, Europe, None)
# 329                      East Coast          (__UNKNOWN, Europe, None)
# 330                      California          (__UNKNOWN, Europe, None)
# 331                     Toronto, ON          (__UNKNOWN, Europe, None)
# 332                             NaN          (__UNKNOWN, Europe, None)
# 333      The Orwellion police-state          (__UNKNOWN, Europe, None)
# 334                     Castaic, CA          (__UNKNOWN, Europe, None)
# 335               Helsinki, Finland          (__UNKNOWN, Europe, None)
# 336                   East Kilbride          (__UNKNOWN, Europe, None)
# 337                             NaN          (__UNKNOWN, Europe, None)
# 338                #FLIGHTCITY UK            (__UNKNOWN, Europe, None)
# 339           middle eastern palace          (__UNKNOWN, Europe, None)
# 340                            Kent          (__UNKNOWN, Europe, None)
# 341                             NaN          (__UNKNOWN, Europe, None)
# 342                             NaN          (__UNKNOWN, Europe, None)
# 343            Nowhere. Everywhere.          (__UNKNOWN, Europe, None)
# 344                #FLIGHTCITY UK            (__UNKNOWN, Europe, None)
# 345                     Perthshire           (__UNKNOWN, Europe, None)
# 346                             NaN          (__UNKNOWN, Europe, None)
# 347                             NaN          (__UNKNOWN, Europe, None)
# 348                             NaN          (__UNKNOWN, Europe, None)
# 349                             NaN          (__UNKNOWN, Europe, None)
# 350                             NaN          (__UNKNOWN, Europe, None)
# 351                             NaN          (__UNKNOWN, Europe, None)
# 352       twitch.tv/naturalemblem26          (__UNKNOWN, Europe, None)
# 353                          cyprus          (__UNKNOWN, Europe, None)
# 354                     Memphis, TN          (__UNKNOWN, Europe, None)
# 355                             NaN          (__UNKNOWN, Europe, None)
# 356                          Studio          (__UNKNOWN, Europe, None)
# 357                   Hollywood, CA          (__UNKNOWN, Europe, None)
# 358                             NaN          (__UNKNOWN, Europe, None)
# 359                        New York          (__UNKNOWN, Europe, None)
# 360                             NaN          (__UNKNOWN, Europe, None)
# 361                             NaN          (__UNKNOWN, Europe, None)
# 362                        Pakistan          (__UNKNOWN, Europe, None)
# 363                     Mexico! ^_^          (__UNKNOWN, Europe, None)
# 364                             NaN          (__UNKNOWN, Europe, None)
# 365                             NaN          (__UNKNOWN, Europe, None)
# 366                     Campinas Sp          (__UNKNOWN, Europe, None)
# 367                             NaN          (__UNKNOWN, Europe, None)
# 368                Harlem, New York          (__UNKNOWN, Europe, None)
# 369                        New York          (__UNKNOWN, Europe, None)
# 370                             NaN          (__UNKNOWN, Europe, None)
# 371                             NaN          (__UNKNOWN, Europe, None)
# 372                             NaN          (__UNKNOWN, Europe, None)
# 373                             NaN          (__UNKNOWN, Europe, None)
# 374                  Washington, DC          (__UNKNOWN, Europe, None)
# 375                      Burbank,CA          (__UNKNOWN, Europe, None)
# 376                        New York          (__UNKNOWN, Europe, None)
# 377                             NaN          (__UNKNOWN, Europe, None)
# 378                             NaN          (__UNKNOWN, Europe, None)
# 379                              ?   (__UNKNOWN, __UNKNOWN, __UNKNOWN)
# 380                             NaN          (__UNKNOWN, Europe, None)
# 381             Spokane, Washington          (__UNKNOWN, Europe, None)
# 382                             USA          (__UNKNOWN, Europe, None)
# 383                   Charlotte, NC          (__UNKNOWN, Europe, None)
# 384                Our Empire State          (__UNKNOWN, Europe, None)
# 385                             NaN          (__UNKNOWN, Europe, None)
# 386                             NaN          (__UNKNOWN, Europe, None)
# 387                       Jerusalem          (__UNKNOWN, Europe, None)
# 388          Kingston, Pennsylvania          (__UNKNOWN, Europe, None)
# 389                   Milwaukee, WI          (__UNKNOWN, Europe, None)
# 390                     Zero Branco          (__UNKNOWN, Europe, None)
# 391               Republic of Texas          (__UNKNOWN, Europe, None)
# 392                             NaN          (__UNKNOWN, Europe, None)
# 393                          bajaur          (__UNKNOWN, Europe, None)
# 394                             USA          (__UNKNOWN, Europe, None)
# 395                  Eldoret, kenya          (__UNKNOWN, Europe, None)
# 396                       ÛÊÛÊÛÊ          (__UNKNOWN, Europe, None)
# 397                       Jerusalem          (__UNKNOWN, Europe, None)
# 398                        Miami,FL          (__UNKNOWN, Europe, None)
# 399                             NaN          (__UNKNOWN, Europe, None)
# 400                 Los Angeles, CA          (__UNKNOWN, Europe, None)
# 401    North-East Region, Singapore          (__UNKNOWN, Europe, None)
# 402                  Eldoret, kenya          (__UNKNOWN, Europe, None)
# 403                             NaN          (__UNKNOWN, Europe, None)
# 404                         Chicago          (__UNKNOWN, Europe, None)
# 405                          EARTH           (__UNKNOWN, Europe, None)
# 406               Jerusalem, Israel          (__UNKNOWN, Europe, None)
# 407                             NaN          (__UNKNOWN, Europe, None)
# 408                     Menasha, WI          (__UNKNOWN, Europe, None)
# 409                             NaN          (__UNKNOWN, Europe, None)
# 410                             NaN          (__UNKNOWN, Europe, None)
# 411                             NaN          (__UNKNOWN, Europe, None)
# 412                              ss          (__UNKNOWN, Europe, None)
# 413                         Atlanta          (__UNKNOWN, Europe, None)
# 414                           Earth          (__UNKNOWN, Europe, None)
# 415                              ss          (__UNKNOWN, Europe, None)
# 416                       Worldwide          (__UNKNOWN, Europe, None)
# 417                     Bleak House          (__UNKNOWN, Europe, None)
# 418            heccfidmss@gmail.com          (__UNKNOWN, Europe, None)
# 419                              ss          (__UNKNOWN, Europe, None)
# 420                         toronto          (__UNKNOWN, Europe, None)
# 421              [ Blonde Bi Fry. ]          (__UNKNOWN, Europe, None)
# 422                         America          (__UNKNOWN, Europe, None)
# 423         NYC :) Ex- #Islamophobe          (__UNKNOWN, Europe, None)
# 424                     SF Bay Area          (__UNKNOWN, Europe, None)
# 425       Orange County, California          (__UNKNOWN, Europe, None)
# 426                              ss          (__UNKNOWN, Europe, None)
# 427   Winston Salem, North Carolina          (__UNKNOWN, Europe, None)
# 428                              ss          (__UNKNOWN, Europe, None)
# 429                             NaN          (__UNKNOWN, Europe, None)
# 430       Adelaide, South Australia          (__UNKNOWN, Europe, None)
# 431                              ss          (__UNKNOWN, Europe, None)
# 432                   WASHINGTON,DC          (__UNKNOWN, Europe, None)
# 433                             NaN          (__UNKNOWN, Europe, None)
# 434                      California          (__UNKNOWN, Europe, None)
# 435                              ss          (__UNKNOWN, Europe, None)
# 436        snapchat // fvck_casper           (__UNKNOWN, Europe, None)
# 437                        New York          (__UNKNOWN, Europe, None)
# 438                             NaN          (__UNKNOWN, Europe, None)
# 439                              ss          (__UNKNOWN, Europe, None)
# 440                              ss          (__UNKNOWN, Europe, None)
# 441                              ss          (__UNKNOWN, Europe, None)
# 442                             NaN          (__UNKNOWN, Europe, None)
# 443                   United States          (__UNKNOWN, Europe, None)
# 444                             NaN          (__UNKNOWN, Europe, None)
# 445                             NaN          (__UNKNOWN, Europe, None)
# 446                      Dallas, TX          (__UNKNOWN, Europe, None)
# 447                             NYC          (__UNKNOWN, Europe, None)
# 448                             NaN          (__UNKNOWN, Europe, None)
# 449                        Location          (__UNKNOWN, Europe, None)
# 450       Selena | Britney | Hilary          (__UNKNOWN, Europe, None)
# 451                             NaN          (__UNKNOWN, Europe, None)
# 452                             NaN          (__UNKNOWN, Europe, None)
# 453                         Ireland          (__UNKNOWN, Europe, None)
# 454                Freeport IL. USA          (__UNKNOWN, Europe, None)
# 455                             NaN          (__UNKNOWN, Europe, None)
# 456                           Dubai          (__UNKNOWN, Europe, None)
# 457                      Tucson, Az          (__UNKNOWN, Europe, None)
# 458                           India          (__UNKNOWN, Europe, None)
# 459                      Seattle WA          (__UNKNOWN, Europe, None)
# 460                             NaN          (__UNKNOWN, Europe, None)
# 461                     Bellevue NE          (__UNKNOWN, Europe, None)
# 462           West Bank, Gaza Strip          (__UNKNOWN, Europe, None)
# 463                       Û¢FLGÛ¢          (__UNKNOWN, Europe, None)
# 464                             NaN          (__UNKNOWN, Europe, None)
# 465        Scotland, United Kingdom          (__UNKNOWN, Europe, None)
# 466                             NaN          (__UNKNOWN, Europe, None)
# 467  Online 24/7. Not even kidding.          (__UNKNOWN, Europe, None)
# 468                             NaN          (__UNKNOWN, Europe, None)
# 469                  rowyso dallas           (__UNKNOWN, Europe, None)
# 470                 Halton, Ontario          (__UNKNOWN, Europe, None)
# 471                          Mumbai          (__UNKNOWN, Europe, None)
# 472                portland, oregon          (__UNKNOWN, Europe, None)
# 473      FIMAK A.S Ist Bolge Muduru          (__UNKNOWN, Europe, None)
# 474                             NaN          (__UNKNOWN, Europe, None)
# 475                         London.          (__UNKNOWN, Europe, None)
# 476               #UNITE THE BLUE            (__UNKNOWN, Europe, None)
# 477                             NaN          (__UNKNOWN, Europe, None)
# 478                    Dayton, Ohio          (__UNKNOWN, Europe, None)
# 479                             NaN          (__UNKNOWN, Europe, None)
# 480                          Global          (__UNKNOWN, Europe, None)
# 481                              ph          (__UNKNOWN, Europe, None)
# 482                 Port Jervis, NY          (__UNKNOWN, Europe, None)
# 483                     City Of Joy          (__UNKNOWN, Europe, None)
# 484                 Los Angeles, CA          (__UNKNOWN, Europe, None)
# 485                      Texas, USA          (__UNKNOWN, Europe, None)
# 486          1/3 of the blam squad           (__UNKNOWN, Europe, None)
# 487                            CCH           (__UNKNOWN, Europe, None)
# 488                             atx          (__UNKNOWN, Europe, None)
# 489                       MAURITIUS          (__UNKNOWN, Europe, None)
# 490                  AKRON OHIO USA          (__UNKNOWN, Europe, None)
# 491                             NaN          (__UNKNOWN, Europe, None)
# 492                             NaN          (__UNKNOWN, Europe, None)
# 493                             NaN          (__UNKNOWN, Europe, None)
# 494                             NaN          (__UNKNOWN, Europe, None)
# 495                          London          (__UNKNOWN, Europe, None)
# 496        london / st catharines ?          (__UNKNOWN, Europe, None)
# 497                             NaN          (__UNKNOWN, Europe, None)
# 498                        Peshawar          (__UNKNOWN, Europe, None)
# 499                             NaN          (__UNKNOWN, Europe, None)
